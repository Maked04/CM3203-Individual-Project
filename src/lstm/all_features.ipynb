# %%
## Imports 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import LSTM, Dense, Dropout # type: ignore

from src.data_processing.lstm_data_preprocessing import get_token_features, get_sliding_windows
from src.data_processing.loader import load_token_data
from src.data_processing.processor import remove_price_anomalies
from src.visualisation.price_plotter import plot_token_price

# %%
# Load and prep data

token_address = "WUb891xiehvvaDURF1r5ZBcbKULPQHcSnNtLfywpump"
sequence_length = 10
# Load data
df = load_token_data(token_address)
    
# Clean data for price features
cleaned_df = remove_price_anomalies(df)

feature_matrix = get_token_features(token_address)

X, y = get_sliding_windows(feature_matrix, sequence_length=sequence_length, prediction_horizon=1)

# Normalize the features (important for LSTM models)
# Apply scaling only to the features (not the targets)
feature_scaler = MinMaxScaler(feature_range=(0, 1))

# Reshape X to 2D for scaling then back to 3D
num_samples, time_steps, features = X.shape
X_reshaped = X.reshape(num_samples * time_steps, features)
X_scaled = feature_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(num_samples, time_steps, features)

# Scale the target variable y
y_scaler = MinMaxScaler(feature_range=(0, 1))
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, shuffle=False
)
# Out:
# Using these changes: [0.02466509]
# Using these changes: [-0.00458034]
# Using these changes: [-0.00031502]
# Using these changes: [0.01333806]
# Using these changes: [-0.00275449]
# Using these changes: [0.00667902]
# Using these changes: [0.0022684]
# Using these changes: [-0.00544227]
# Using these changes: [0.0046827]
# Using these changes: [0.0047246]
# Using these changes: [-0.02491677]
# Using these changes: [-0.0120508]
# Using these changes: [-0.00039371]
# Using these changes: [0.00293603]
# Using these changes: [-0.00022907]
# Using these changes: [-0.00238803]
# Using these changes: [0.00919372]
# Using these changes: [0.01032515]
# Using these changes: [0.00187951]
# Using these changes: [-0.00173138]
# Using these changes: [-0.0017366]
# Using these changes: [-0.04686528]
# Using these changes: [0.02488679]
# Using these changes: [-0.04808246]
# Using these changes: [-0.00341265]
# Using these changes: [0.01414904]
# Using these changes: [-0.02478457]
# Using these changes: [0.00174647]
# Using these changes: [0.00839018]
# Using these changes: [-0.01387862]
# Using these changes: [-0.00841897]
# Using these changes: [-0.0103051]
# Using these changes: [-0.0222205]
# Using these changes: [-0.02715198]
# Using these changes: [-0.02657953]
# Using these changes: [0.01422241]
# Using these changes: [-0.02639446]
# Using these changes: [-0.00443817]
# Using these changes: [-0.0211079]
# Using these changes: [-0.0038701]
# Using these changes: [0.00075792]
# Using these changes: [-0.00063704]
# Using these changes: [0.08632792]
# Using these changes: [-0.03976353]
# Using these changes: [0.08822436]
# Using these changes: [-0.0240303]
# Using these changes: [0.03128288]
# Using these changes: [0.02723776]
# Using these changes: [-0.01350466]
# Using these changes: [0.01797297]
# Using these changes: [0.02967038]
# Using these changes: [-0.03225183]
# Using these changes: [0.07020279]
# Using these changes: [0.00135828]
# Using these changes: [0.00120234]
# Using these changes: [0.0055381]
# Using these changes: [0.00628359]
# Using these changes: [0.03415338]
# Using these changes: [-0.00593073]
# Using these changes: [-0.01516425]
# Using these changes: [0.06017508]
# Using these changes: [0.44760067]
# Using these changes: [-0.10657993]
# Using these changes: [-0.13591405]
# Using these changes: [0.42915168]
# Using these changes: [-0.09404129]
# Using these changes: [0.08027482]
# Using these changes: [-0.06237712]
# Using these changes: [-0.01189084]
# Using these changes: [0.0787978]
# Using these changes: [-0.00311674]
# Using these changes: [-0.01530806]
# Using these changes: [-0.03324134]
# Using these changes: [-0.00854377]
# Using these changes: [0.07398343]
# Using these changes: [-0.00454371]
# Using these changes: [-0.11499746]
# Using these changes: [-0.03321509]
# Using these changes: [0.08060319]
# Using these changes: [0.01163335]
# Using these changes: [-0.02137647]
# Using these changes: [0.04455407]
# Using these changes: [0.01809675]
# Using these changes: [-0.02671621]
# Using these changes: [0.02463782]
# Using these changes: [0.01666958]
# Using these changes: [-0.04412055]
# Using these changes: [-0.00028267]
# Using these changes: [0.00538017]
# Using these changes: [-0.00102659]
# Using these changes: [-0.00169209]
# Using these changes: [0.00368292]
# Using these changes: [-0.03152867]
# Using these changes: [0.01621665]
# Using these changes: [0.0011802]
# Using these changes: [0.00704059]
# Using these changes: [-0.03691096]
# Using these changes: [0.00217986]
# Using these changes: [-0.00037582]
# Using these changes: [0.00086739]
# Using these changes: [-3.49577641e-05]
# Using these changes: [0.05350473]
# Using these changes: [0.00048609]
# Using these changes: [0.0023976]
# Using these changes: [0.00269006]
# Using these changes: [-0.00623537]
# Using these changes: [-0.02223074]
# Using these changes: [-0.02177302]
# Using these changes: [0.04173852]
# Using these changes: [-0.00725997]
# Using these changes: [0.00119295]
# Using these changes: [-0.03864185]
# Using these changes: [0.02222555]
# Using these changes: [-0.05847564]
# Using these changes: [0.1231146]
# Using these changes: [0.00233078]
# Using these changes: [0.00487576]
# Using these changes: [0.01024288]
# Using these changes: [0.03396813]
# Using these changes: [-0.01588225]
# Using these changes: [0.09264033]
# Using these changes: [0.06813614]
# Using these changes: [-0.01040118]
# Using these changes: [0.08273819]
# Using these changes: [0.00134971]
# Using these changes: [0.00335037]
# Using these changes: [-0.01903897]
# Using these changes: [-0.04316855]
# Using these changes: [0.06370189]
# Using these changes: [0.00787541]
# Using these changes: [-0.00164067]
# Using these changes: [0.01254447]
# Using these changes: [-0.00740212]
# Using these changes: [-0.00781568]
# Using these changes: [0.01769712]
# Using these changes: [-0.00110924]
# Using these changes: [-0.00380502]
# Using these changes: [-0.01504039]
# Using these changes: [0.00252259]
# Using these changes: [0.03047677]
# Using these changes: [0.02700703]
# Using these changes: [-0.01002105]
# Using these changes: [-0.0026186]
# Using these changes: [0.03285087]
# Using these changes: [-0.00473141]
# Using these changes: [-0.00549709]
# Using these changes: [-0.22284166]
# Using these changes: [0.14015801]
# Using these changes: [-0.12058897]
# Using these changes: [-0.13530006]
# Using these changes: [0.00015302]
# Using these changes: [-0.00064376]
# Using these changes: [0.05092]
# Using these changes: [0.07742814]
# Using these changes: [-0.06865355]
# Using these changes: [-0.02303001]
# Using these changes: [-0.02504943]
# Using these changes: [0.05958227]
# Using these changes: [0.00123187]
# Using these changes: [-0.00052612]
# Using these changes: [-0.00267076]
# Using these changes: [-0.01493644]
# Using these changes: [0.00536537]
# Using these changes: [9.93332479e-05]
# Using these changes: [0.00386201]
# Using these changes: [0.02265607]
# Using these changes: [0.0712745]
# Using these changes: [-0.00196308]
# Using these changes: [-0.00265609]
# Using these changes: [-0.00816054]
# Using these changes: [-0.0203646]
# Using these changes: [0.0519486]
# Using these changes: [-0.00311848]
# Using these changes: [-0.00807745]
# Using these changes: [0.03590983]
# Using these changes: [-0.0123934]
# Using these changes: [0.04250774]
# Using these changes: [0.03603336]
# Using these changes: [-0.00304029]
# Using these changes: [-0.00303566]
# Using these changes: [0.02122742]
# Using these changes: [-0.00674994]
# Using these changes: [0.03698943]
# Using these changes: [-0.00870726]
# Using these changes: [-0.00858839]
# Using these changes: [-0.00181512]
# Using these changes: [-0.00394064]
# Using these changes: [-0.00476443]
# Using these changes: [0.02922934]
# Using these changes: [0.00010925]
# Using these changes: [0.00071222]
# Using these changes: [0.0705213]
# Using these changes: [-0.00017588]
# Using these changes: [-0.00086502]
# Using these changes: [-0.02656959]
# Using these changes: [-0.03255487]
# Using these changes: [0.07880251]
# Using these changes: [-0.01359175]
# Using these changes: [-0.00092365]
# Using these changes: [-0.00929266]
# Using these changes: [0.00011116]
# Using these changes: [0.02081316]
# Using these changes: [-0.01657125]
# Using these changes: [-0.00332622]
# Using these changes: [0.00167366]
# Using these changes: [0.00516541]
# Using these changes: [0.00896397]
# Using these changes: [-0.00791006]
# Using these changes: [-0.00202335]
# Using these changes: [0.00524017]
# Using these changes: [-0.00727215]
# Using these changes: [-0.00579814]
# Using these changes: [-0.02225399]
# Using these changes: [0.02194644]
# Using these changes: [-0.04284633]
# Using these changes: [0.0014764]
# Using these changes: [0.01057877]
# Using these changes: [-0.00298395]
# Using these changes: [-0.00405373]
# Using these changes: [-0.00252583]
# Using these changes: [3.28583335e-05]
# Using these changes: [-0.00885827]
# Using these changes: [-0.02126435]
# Using these changes: [0.00975552]
# Using these changes: [0.00715505]
# Using these changes: [-0.00166057]
# Using these changes: [-0.02207091]
# Using these changes: [0.00460712]
# Using these changes: [-0.01212023]
# Using these changes: [0.0020138]
# Using these changes: [-0.0187046]
# Using these changes: [0.00997003]
# Using these changes: [-0.0768847]
# Using these changes: [-0.06316037]
# Using these changes: [-0.02235674]
# Using these changes: [0.00670713]
# Using these changes: [0.00902766]
# Using these changes: [0.00520354]
# Using these changes: [-0.05855251]
# Using these changes: [0.04160119]
# Using these changes: [-0.0005229]
# Using these changes: [-0.06700159]
# Using these changes: [-0.00029553]
# Using these changes: [-0.00463477]
# Using these changes: [-0.00527662]
# Using these changes: [-0.0008583]
# Using these changes: [0.07357155]
# Using these changes: [-0.036597]
# Using these changes: [-0.0363232]
# Using these changes: [0.14394844]
# Using these changes: [-0.0112728]
# Using these changes: [-0.01865972]
# Using these changes: [-0.01496103]
# Using these changes: [0.05550799]
# Using these changes: [-0.00431665]
# Using these changes: [-0.02328692]
# Using these changes: [-0.00870421]
# Using these changes: [-0.00475675]
# Using these changes: [0.02276799]
# Using these changes: [0.02406063]
# Using these changes: [-0.00245973]
# Using these changes: [-0.01754575]
# Using these changes: [-0.00701251]
# Using these changes: [0.05966417]
# Using these changes: [-0.03526785]
# Using these changes: [0.06621359]
# Using these changes: [-0.00106821]
# Using these changes: [-0.00069493]
# Using these changes: [0.01420486]
# Using these changes: [0.00667736]
# Using these changes: [0.00725335]
# Using these changes: [0.01208493]
# Using these changes: [0.02908313]
# Using these changes: [-0.00045591]
# Using these changes: [-0.00016141]
# Using these changes: [-0.00049867]
# Using these changes: [0.01422479]
# Using these changes: [0.00407603]
# Using these changes: [-0.00851446]
# Using these changes: [-0.02843389]
# Using these changes: [-0.02791972]
# Using these changes: [0.02154305]
# Using these changes: [-0.0106059]
# Using these changes: [0.01205607]
# Using these changes: [-0.01961122]
# Using these changes: [-0.00195044]
# Using these changes: [-0.00101741]
# Using these changes: [0.01192859]
# Using these changes: [-0.00729419]
# Using these changes: [-0.00059423]
# Using these changes: [0.00380656]
# Using these changes: [-0.00261009]
# Using these changes: [0.00378902]
# Using these changes: [-0.00398148]
# Using these changes: [0.00186973]
# Using these changes: [0.00488333]
# Using these changes: [0.0567323]
# Using these changes: [-0.00156226]
# Using these changes: [-0.02701575]
# Using these changes: [0.00510758]
# Using these changes: [-0.01340466]
# Using these changes: [-0.00660912]
# Using these changes: [0.01064392]
# Using these changes: [0.00518563]
# Using these changes: [-0.00179628]
# Using these changes: [0.00560923]
# Using these changes: [0.0099853]
# Using these changes: [-0.00453908]
# Using these changes: [0.04416042]
# Using these changes: [-0.00440267]
# Using these changes: [-0.01769588]
# Using these changes: [0.02170474]
# Using these changes: [0.02354359]
# Using these changes: [-0.01406157]
# Using these changes: [-0.00548949]
# Using these changes: [0.03496121]
# Using these changes: [-0.00163101]
# Using these changes: [0.00629336]
# Using these changes: [0.02903494]
# Using these changes: [-0.00673972]
# Using these changes: [-0.00735803]
# Using these changes: [-0.00620161]
# Using these changes: [0.02527858]
# Using these changes: [-0.00265211]
# Using these changes: [0.01016426]
# Using these changes: [-0.0006061]
# Using these changes: [0.00701538]
# Using these changes: [-0.01351028]
# Using these changes: [-0.00121246]
# Using these changes: [0.0006194]
# Using these changes: [-0.00040958]
# Using these changes: [-0.01746716]
# Using these changes: [-0.00610557]
# Using these changes: [-0.00340027]
# Using these changes: [0.01422403]
# Using these changes: [-0.00060319]
# Using these changes: [-0.0015061]
# Using these changes: [0.01119817]
# Using these changes: [-0.00974433]
# Using these changes: [0.00175992]
# Using these changes: [-0.0009807]
# Using these changes: [0.02755959]
# Using these changes: [-0.00204734]
# Using these changes: [-0.00203505]
# Using these changes: [0.01207653]
# Using these changes: [0.02058583]
# Using these changes: [-0.01303911]
# Using these changes: [0.02730191]
# Using these changes: [-0.00231408]
# Using these changes: [0.0408732]
# Using these changes: [0.06156901]
# Using these changes: [0.02418683]
# Using these changes: [0.05118222]
# Using these changes: [-0.02509434]
# Using these changes: [0.02612541]
# Using these changes: [0.0011103]
# Using these changes: [0.00250284]
# Using these changes: [-0.08066245]
# Using these changes: [-0.00332432]
# Using these changes: [0.03591546]
# Using these changes: [0.04156922]
# Using these changes: [0.00308914]
# Using these changes: [-0.06971769]
# Using these changes: [-0.00313368]
# Using these changes: [0.01833942]
# Using these changes: [0.00546607]
# Using these changes: [-0.00119167]
# Using these changes: [0.00426118]
# Using these changes: [-0.02729189]
# Using these changes: [0.02629343]
# Using these changes: [-0.04421986]
# Using these changes: [-0.03567928]
# Using these changes: [-0.00435434]
# Using these changes: [0.02212452]
# Using these changes: [0.00288741]
# Using these changes: [-0.00210369]
# Using these changes: [-0.00671183]
# Using these changes: [-0.00508079]
# Using these changes: [-0.00067957]
# Using these changes: [-0.00244954]
# Using these changes: [0.02409338]
# Using these changes: [0.05061796]
# Using these changes: [-0.02291704]
# Using these changes: [-0.02164585]
# Using these changes: [0.04722021]
# Using these changes: [0.00790429]
# Using these changes: [-0.00395147]
# Using these changes: [0.01812497]
# Using these changes: [-0.00094086]
# Using these changes: [-0.00631053]
# Using these changes: [0.00603388]
# Using these changes: [0.0019933]
# Using these changes: [-0.00233144]
# Using these changes: [0.00250881]
# Using these changes: [0.00040352]
# Using these changes: [0.00091853]
# Using these changes: [0.00127656]
# Using these changes: [0.00069659]
# Using these changes: [-0.00147773]
# Using these changes: [-0.00044837]
# Using these changes: [0.00293018]
# Using these changes: [-0.00122696]
# Using these changes: [-0.01196411]
# Using these changes: [-0.13860213]
# Using these changes: [-0.00371326]
# Using these changes: [0.0046026]
# Using these changes: [0.00568995]
# Using these changes: [0.06762509]
# Using these changes: [0.06653702]
# Using these changes: [-0.12950282]
# Using these changes: [-0.00539615]
# Using these changes: [0.00280491]
# Using these changes: [0.00385714]
# Using these changes: [-0.04815179]
# Using these changes: [0.0430249]
# Using these changes: [-0.06457225]
# Using these changes: [-4.39018924e-05]
# Using these changes: [-0.0048019]
# Using these changes: [0.01633691]
# Using these changes: [-0.00317069]
# Using these changes: [-0.00310972]
# Using these changes: [-0.00452487]
# Using these changes: [-0.0025436]
# Using these changes: [-0.00076973]
# Using these changes: [0.0007796]
# Using these changes: [0.02673431]
# Using these changes: [-0.00300356]
# Using these changes: [-0.00379555]
# Using these changes: [-0.00255436]
# Using these changes: [-0.00183952]
# Using these changes: [-0.00112782]
# Using these changes: [-0.00306689]
# Using these changes: [-0.00157489]
# Using these changes: [0.00402914]
# Using these changes: [0.00354834]
# Using these changes: [-0.00052453]
# Using these changes: [-0.04175427]
# Using these changes: [-0.05401503]
# Using these changes: [0.01018384]
# Using these changes: [0.00183053]
# Using these changes: [-0.00912647]
# Using these changes: [-0.08908975]
# Using these changes: [-0.00030827]
# Using these changes: [0.04710572]
# Using these changes: [0.00955232]
# Using these changes: [0.00065772]
# Using these changes: [-0.02556014]
# Using these changes: [-0.02787798]
# Using these changes: [0.0734913]
# Using these changes: [-0.00535119]
# Using these changes: [0.01232138]
# Using these changes: [0.0038843]
# Using these changes: [-0.01153166]
# Using these changes: [-0.01091635]
# Using these changes: [-0.03178737]
# Using these changes: [0.03583254]
# Using these changes: [0.04157607]
# Using these changes: [0.01016429]
# Using these changes: [-0.01945876]
# Using these changes: [-0.02739855]
# Using these changes: [0.00221611]
# Using these changes: [-0.00195844]
# Using these changes: [-0.0309037]
# Using these changes: [-0.0273831]
# Using these changes: [0.09728554]
# Using these changes: [-0.13808819]
# Using these changes: [-0.00870766]
# Using these changes: [0.01501977]
# Using these changes: [0.03813141]
# Using these changes: [0.0510491]
# Using these changes: [0.0373549]
# Using these changes: [-0.10100002]
# Using these changes: [-0.01045688]
# Using these changes: [0.03258781]
# Using these changes: [-0.00453653]
# Using these changes: [-0.00176776]
# Using these changes: [-0.00124249]
# Using these changes: [0.02186912]
# Using these changes: [-0.00151157]
# Using these changes: [-0.00223871]
# Using these changes: [-0.00021014]
# Using these changes: [0.00238636]
# Using these changes: [-0.00353567]
# Using these changes: [-0.00501219]
# Using these changes: [0.02430756]
# Using these changes: [0.0028623]
# Using these changes: [-0.01420976]
# Using these changes: [-0.00151613]
# Using these changes: [0.01732297]
# Using these changes: [-0.00253145]
# Using these changes: [-0.00379497]
# Using these changes: [-0.00126806]
# Using these changes: [0.00806882]
# Using these changes: [0.00663112]
# Using these changes: [-0.00569944]
# Using these changes: [-0.01636098]
# Using these changes: [-0.02000538]
# Using these changes: [-0.00478793]
# Using these changes: [-0.00231909]
# Using these changes: [0.01313642]
# Using these changes: [-0.0014833]
# Using these changes: [-0.00047966]
# Using these changes: [-0.00087454]
# Using these changes: [-0.00186513]
# Using these changes: [0.00351646]
# Using these changes: [0.00137967]
# Using these changes: [-0.11569923]
# Using these changes: [-0.00086037]
# Using these changes: [0.00821437]
# Using these changes: [0.00582018]
# Using these changes: [0.05568729]
# Using these changes: [-0.19720585]
# Using these changes: [0.02436304]
# Using these changes: [-0.00027942]
# Using these changes: [0.00396272]
# Using these changes: [0.06719343]
# Using these changes: [-0.11387557]
# Using these changes: [0.00649293]
# Using these changes: [-0.00028141]
# Using these changes: [-0.00602923]
# Using these changes: [-0.00520541]
# Using these changes: [0.00183062]
# Using these changes: [0.00457813]
# Using these changes: [0.00602245]
# Using these changes: [-0.00611743]
# Using these changes: [-0.00302018]
# Using these changes: [0.0037868]
# Using these changes: [0.00130665]
# Using these changes: [-0.00152306]
# Using these changes: [0.01119728]
# Using these changes: [0.01293901]
# Using these changes: [-0.01626288]
# Using these changes: [-0.10174863]
# Using these changes: [0.05245497]
# Using these changes: [0.01822016]
# Using these changes: [-0.01223967]
# Using these changes: [0.02010499]
# Using these changes: [0.00353905]
# Using these changes: [0.00276302]
# Using these changes: [0.00130398]
# Using these changes: [0.01067092]
# Using these changes: [-0.09693923]
# Using these changes: [-0.00945354]
# Using these changes: [0.00949061]
# Using these changes: [0.01390497]
# Using these changes: [0.01815114]
# Using these changes: [-0.00582904]
# Using these changes: [-0.00954665]
# Using these changes: [0.07683888]
# Using these changes: [0.01840303]
# Using these changes: [0.00671498]
# Using these changes: [0.00687957]
# Using these changes: [0.00510251]
# Using these changes: [-0.04683475]
# Using these changes: [-0.04830762]
# Using these changes: [0.05559912]
# Using these changes: [0.08382893]
# Using these changes: [-0.02335364]
# Using these changes: [-0.0177183]
# Using these changes: [-0.01488786]
# Using these changes: [0.03512614]
# Using these changes: [-0.00607293]
# Using these changes: [-0.00593753]
# Using these changes: [0.00086186]
# Using these changes: [0.01925787]
# Using these changes: [-0.00749221]
# Using these changes: [0.00378444]
# Using these changes: [-0.0016894]
# Using these changes: [-0.00141805]
# Using these changes: [0.03632623]
# Using these changes: [0.02360226]
# Using these changes: [0.02063611]
# Using these changes: [-0.02914224]
# Using these changes: [0.09077124]
# Using these changes: [-0.00049939]
# Using these changes: [-0.01659008]
# Using these changes: [-0.01215649]
# Using these changes: [0.00377082]
# Using these changes: [-0.00119725]
# Using these changes: [0.05988448]
# Using these changes: [-0.02981257]
# Using these changes: [0.14072875]
# Using these changes: [0.00287933]
# Using these changes: [-0.01961672]
# Using these changes: [-0.01878295]
# Using these changes: [0.02653402]
# Using these changes: [-0.01886307]
# Using these changes: [0.02760088]
# Using these changes: [0.00102804]
# Using these changes: [-0.00149776]
# Using these changes: [0.0002475]
# Using these changes: [-0.01544253]
# Using these changes: [-0.00343865]
# Using these changes: [-0.00174547]
# Using these changes: [0.01448571]
# Using these changes: [0.01174106]
# Using these changes: [-0.11242419]
# Using these changes: [-0.00925621]
# Using these changes: [-0.00413008]
# Using these changes: [0.03586238]
# Using these changes: [0.05916634]
# Using these changes: [-0.0651141]
# Using these changes: [0.01958874]
# Using these changes: [0.01750515]
# Using these changes: [-0.00671663]
# Using these changes: [-0.00356337]
# Using these changes: [-0.0049132]
# Using these changes: [-0.00613498]
# Using these changes: [-0.00230449]
# Using these changes: [-0.0083395]
# Using these changes: [-0.00497567]
# Using these changes: [0.00820352]
# Using these changes: [-0.00780748]
# Using these changes: [-0.0020529]
# Using these changes: [0.01411784]
# Using these changes: [0.01445022]
# Using these changes: [-0.0051041]
# Using these changes: [-0.00531424]
# Using these changes: [-0.00746181]
# Using these changes: [0.01308068]
# Using these changes: [-0.00425658]
# Using these changes: [-0.00742604]
# Using these changes: [-0.00127886]
# Using these changes: [0.00730087]
# Using these changes: [-0.00443341]
# Using these changes: [-7.83328647e-05]
# Using these changes: [-0.00578242]
# Using these changes: [0.00018157]
# Using these changes: [0.00362618]
# Using these changes: [-0.00070949]
# Using these changes: [0.00574592]
# Using these changes: [-0.03431998]
# Using these changes: [-0.00292803]
# Using these changes: [0.02691196]
# Using these changes: [0.02253136]
# Using these changes: [-0.00690908]
# Using these changes: [-0.04295985]
# Using these changes: [0.00071659]
# Using these changes: [-0.00213547]
# Using these changes: [-0.00213247]
# Using these changes: [0.0054173]
# Using these changes: [0.00043739]
# Using these changes: [0.00129211]
# Using these changes: [0.01258122]
# Using these changes: [-0.01171607]
# Using these changes: [0.03682577]
# Using these changes: [-0.00682652]
# Using these changes: [-0.00301129]
# Using these changes: [0.01519268]
# Using these changes: [0.001645]
# Using these changes: [-0.00164127]
# Using these changes: [0.07033271]
# Using these changes: [-0.00763188]
# Using these changes: [0.00030196]
# Using these changes: [-0.00091549]
# Using these changes: [-0.00622805]
# Using these changes: [-0.00543818]
# Using these changes: [-0.00133104]
# Using these changes: [-0.00211053]
# Using these changes: [-0.01935074]
# Using these changes: [-0.01815025]
# Using these changes: [-0.0003633]
# Using these changes: [-0.00229785]
# Using these changes: [0.07255563]
# Using these changes: [0.01029989]
# Using these changes: [-0.00491488]
# Using these changes: [0.03781929]
# Using these changes: [-0.00302507]
# Using these changes: [-0.01515524]
# Using these changes: [0.02430093]
# Using these changes: [-0.00342778]
# Using these changes: [-0.01984604]
# Using these changes: [0.02806369]
# Using these changes: [-0.02638903]
# Using these changes: [-0.00276049]
# Using these changes: [-0.0142729]
# Using these changes: [0.02269145]
# Using these changes: [-0.00345676]
# Using these changes: [0.06823925]
# Using these changes: [-0.00298535]
# Using these changes: [-0.00252954]
# Using these changes: [-0.01265578]
# Using these changes: [-0.02633949]
# Using these changes: [-0.01382546]
# Using these changes: [0.07666265]
# Using these changes: [-0.00278216]
# Using these changes: [-0.00277832]
# Using these changes: [-0.00277443]
# Using these changes: [-0.00276734]
# Using these changes: [-0.00203258]
# Using these changes: [-0.00136575]
# Using these changes: [0.0230314]
# Using these changes: [-0.00406544]
# Using these changes: [0.01279077]
# Using these changes: [-0.00451242]
# Using these changes: [0.0183086]
# Using these changes: [-0.00143284]
# Using these changes: [-0.00026943]
# Using these changes: [2.67226384e-05]
# Using these changes: [-0.00502843]
# Using these changes: [0.01380715]
# Using these changes: [-0.00171523]
# Using these changes: [-0.00270071]
# Using these changes: [0.00724472]
# Using these changes: [0.00728364]
# Using these changes: [-0.00409769]
# Using these changes: [-0.000979]
# Using these changes: [0.01749518]
# Using these changes: [-0.00323907]
# Using these changes: [-0.04128393]
# Using these changes: [0.0013944]
# Using these changes: [0.02139657]
# Using these changes: [-0.01799912]
# Using these changes: [-0.01033778]
# Using these changes: [0.02397802]
# Using these changes: [-0.00034761]
# Using these changes: [0.00118798]
# Using these changes: [0.00088402]
# Using these changes: [-0.00296499]
# Using these changes: [-0.00263031]
# Using these changes: [-0.00316403]
# Using these changes: [-0.00031715]
# Using these changes: [0.00174403]
# Using these changes: [0.00131396]
# Using these changes: [0.00386885]
# Using these changes: [0.00125926]
# Using these changes: [-0.04626105]
# Using these changes: [-0.04403275]
# Using these changes: [-0.00667612]
# Using these changes: [0.0080778]
# Using these changes: [-0.03492674]
# Using these changes: [-0.01937208]
# Using these changes: [-0.00112022]
# Using these changes: [0.00010828]
# Using these changes: [0.00163526]
# Using these changes: [-0.10017029]
# Using these changes: [0.02397277]
# Using these changes: [0.03428001]
# Using these changes: [0.03233311]
# Using these changes: [-0.08999807]
# Using these changes: [0.00238789]
# Using these changes: [0.00431614]
# Using these changes: [-0.00076391]
# Using these changes: [-0.00127642]
# Using these changes: [0.00272342]
# Using these changes: [0.02461644]
# Using these changes: [-0.01548125]
# Using these changes: [-0.00358158]
# Using these changes: [-0.00215295]
# Using these changes: [0.13675872]
# Using these changes: [-0.02823399]
# Using these changes: [-0.00177665]
# Using these changes: [-0.00647267]
# Using these changes: [-0.00675389]
# Using these changes: [-0.00819695]
# Using these changes: [-0.02527618]
# Using these changes: [0.17199955]
# Using these changes: [0.00087336]
# Using these changes: [-0.02741902]
# Using these changes: [0.0262337]
# Using these changes: [0.00810156]
# Using these changes: [-0.00611511]
# Using these changes: [0.02772268]
# Using these changes: [-0.01462979]
# Using these changes: [0.11679682]
# Using these changes: [-0.02654373]
# Using these changes: [-0.02619607]
# Using these changes: [-0.02079348]
# Using these changes: [-0.00795931]
# Using these changes: [0.03776685]
# Using these changes: [0.03183662]
# Using these changes: [0.02921098]
# Using these changes: [-0.05845767]
# Using these changes: [0.00041038]
# Using these changes: [-0.01859182]
# Using these changes: [0.00838285]
# Using these changes: [-0.00855641]
# Using these changes: [-0.009999]
# Using these changes: [0.00530938]
# Using these changes: [0.00460183]
# Using these changes: [-0.02027965]
# Using these changes: [0.00482644]
# Using these changes: [0.00569157]
# Using these changes: [-0.01933557]
# Using these changes: [0.00426875]
# Using these changes: [-0.00042492]
# Using these changes: [0.00177254]
# Using these changes: [0.00160675]
# Using these changes: [-0.00157418]
# Using these changes: [-0.00097818]
# Using these changes: [-9.52635248e-05]
# Using these changes: [-0.00384476]
# Using these changes: [-0.00137371]
# Using these changes: [-0.00373526]
# Using these changes: [0.00075483]
# Using these changes: [0.01126434]
# Using these changes: [0.00445947]
# Using these changes: [-0.00191223]
# Using these changes: [0.0061852]
# Using these changes: [-0.00231596]
# Using these changes: [0.00300821]
# Using these changes: [-0.00116527]
# Using these changes: [-0.02878432]
# Using these changes: [-0.040708]
# Using these changes: [0.01587638]
# Using these changes: [-0.05165449]
# Using these changes: [0.13363915]
# Using these changes: [-0.15899698]
# Using these changes: [-0.00896092]
# Using these changes: [0.00251544]
# Using these changes: [-0.00311637]
# Using these changes: [0.0166452]
# Using these changes: [-0.00479578]
# Using these changes: [-0.00081156]
# Using these changes: [-0.00133086]
# Using these changes: [-0.00503175]
# Using these changes: [0.02652729]
# Using these changes: [-0.00514287]
# Using these changes: [0.00684883]
# Using these changes: [0.00276574]
# Using these changes: [0.03697562]
# Using these changes: [-0.03041514]
# Using these changes: [0.14392404]
# Using these changes: [-0.04126301]
# Using these changes: [0.05422776]
# Using these changes: [-0.00162981]
# Using these changes: [0.00203961]
# Using these changes: [0.01288167]
# Using these changes: [0.0096927]
# Using these changes: [-0.00168766]
# Using these changes: [0.00834754]
# Using these changes: [0.0009429]
# Using these changes: [0.0042993]
# Using these changes: [0.01383325]
# Using these changes: [-0.00623616]
# Using these changes: [0.00029232]
# Using these changes: [-0.04303547]
# Using these changes: [-0.07267172]
# Using these changes: [0.02086994]
# Using these changes: [-0.01029881]
# Using these changes: [-0.03969314]
# Using these changes: [0.02524666]
# Using these changes: [-0.02199318]
# Using these changes: [-0.00325112]
# Using these changes: [0.00109945]
# Using these changes: [0.0025308]
# Using these changes: [0.00087266]
# Using these changes: [-0.00078866]
# Using these changes: [0.00059654]
# Using these changes: [0.00274217]
# Using these changes: [-0.00470582]
# Using these changes: [0.01818609]
# Using these changes: [0.02347415]
# Using these changes: [0.0037206]
# Using these changes: [-0.00335834]
# Using these changes: [-0.00244126]
# Using these changes: [-0.0035123]
# Using these changes: [0.00070686]
# Using these changes: [0.01358158]
# Using these changes: [0.0740524]
# Using these changes: [-0.0315973]
# Using these changes: [0.10408253]
# Using these changes: [-0.0213202]
# Using these changes: [-0.03121294]
# Using these changes: [-0.00711913]
# Using these changes: [0.09462382]
# Using these changes: [-0.01175493]
# Using these changes: [-0.0154018]
# Using these changes: [0.04611981]
# Using these changes: [-0.01483729]
# Using these changes: [-0.00029746]
# Using these changes: [0.03132191]
# Using these changes: [-0.00027196]
# Using these changes: [0.00010472]
# Using these changes: [-0.01699618]
# Using these changes: [0.00907351]
# Using these changes: [-0.0082892]
# Using these changes: [-0.00033492]
# Using these changes: [-0.01272237]
# Using these changes: [-0.02766622]
# Using these changes: [0.01177571]
# Using these changes: [-0.05888452]
# Using these changes: [-0.04337251]
# Using these changes: [0.0007379]
# Using these changes: [0.00152469]
# Using these changes: [0.00089953]
# Using these changes: [3.30843333e-06]
# Using these changes: [-0.00392541]
# Using these changes: [0.00368343]
# Using these changes: [-0.00263168]
# Using these changes: [0.00443787]
# Using these changes: [0.0051955]
# Using these changes: [-0.00122899]
# Using these changes: [-0.00068322]
# Using these changes: [-0.00165045]
# Using these changes: [0.04550544]
# Using these changes: [-0.02566539]
# Using these changes: [-0.00750897]
# Using these changes: [0.06280929]
# Using these changes: [0.01793272]
# Using these changes: [-0.00786639]
# Using these changes: [-0.00645763]
# Using these changes: [0.00506635]
# Using these changes: [0.00022386]
# Using these changes: [0.02930508]
# Using these changes: [-0.00627993]
# Using these changes: [-0.00553083]
# Using these changes: [0.01846344]
# Using these changes: [0.01372584]
# Using these changes: [0.01195256]
# Using these changes: [-0.00134987]
# Using these changes: [0.00095414]
# Using these changes: [-0.02451938]
# Using these changes: [-0.02874854]
# Using these changes: [-0.00828257]
# Using these changes: [0.00504982]
# Using these changes: [0.0016823]
# Using these changes: [-0.00590887]
# Using these changes: [0.00350752]
# Using these changes: [-0.00034097]
# Using these changes: [0.00389686]
# Using these changes: [0.00044885]
# Using these changes: [0.00386904]
# Using these changes: [-0.00278085]
# Using these changes: [0.00798356]
# Using these changes: [0.0038585]
# Using these changes: [-0.00014551]
# Using these changes: [-0.00245387]
# Using these changes: [-0.00118557]
# Using these changes: [-0.00108199]
# Using these changes: [-0.00424872]
# Using these changes: [0.00632823]
# Using these changes: [-0.01536309]
# Using these changes: [-0.00461001]
# Using these changes: [0.01785817]
# Using these changes: [-0.01363765]
# Using these changes: [0.00757467]
# Using these changes: [-0.04199309]
# Using these changes: [0.00080627]
# Using these changes: [0.0173386]
# Using these changes: [-0.04536099]
# Using these changes: [0.01360128]
# Using these changes: [-0.00703506]
# Using these changes: [0.00229654]
# Using these changes: [0.0003383]
# Using these changes: [0.01263331]
# Using these changes: [0.00577944]
# Using these changes: [-0.0051933]
# Using these changes: [-0.01765761]
# Using these changes: [0.00051545]
# Using these changes: [0.0173831]
# Using these changes: [0.0073453]
# Using these changes: [-0.00620193]
# Using these changes: [0.03085295]
# Using these changes: [-0.00642968]
# Using these changes: [-0.00069083]
# Using these changes: [-0.00544314]
# Using these changes: [-0.00571025]
# Using these changes: [0.02755391]
# Using these changes: [-0.00189577]
# Using these changes: [0.00445101]
# Using these changes: [0.00256194]
# Using these changes: [0.01346111]
# Using these changes: [-0.00614732]
# Using these changes: [0.00729391]
# Using these changes: [-0.00049067]
# Using these changes: [0.00903507]
# Using these changes: [0.0107783]
# Using these changes: [0.00246108]
# Using these changes: [0.00184688]
# Using these changes: [-5.91219458e-05]
# Using these changes: [-0.00284094]
# Using these changes: [0.00508062]
# Using these changes: [-0.00142873]
# Using these changes: [-0.00083345]
# Using these changes: [-0.00234508]
# Using these changes: [0.0049172]
# Using these changes: [-0.00727659]
# Using these changes: [0.00629574]
# Using these changes: [-0.01846765]
# Using these changes: [0.00541189]
# Using these changes: [0.00376146]
# Using these changes: [-0.00234428]
# Using these changes: [0.00506509]
# Using these changes: [0.01175783]
# Using these changes: [-0.00483091]
# Using these changes: [0.00600564]
# Using these changes: [-0.01421767]
# Using these changes: [0.00051565]
# Using these changes: [-0.03267427]
# Using these changes: [-0.00174599]
# Using these changes: [0.01713578]
# Using these changes: [-0.0120166]
# Using these changes: [-0.00111426]
# Using these changes: [0.00158663]
# Using these changes: [0.00742076]
# Using these changes: [-0.00419612]
# Using these changes: [0.00780948]
# Using these changes: [0.00092146]
# Using these changes: [0.00275308]
# Using these changes: [0.00828266]
# Using these changes: [-0.00242893]
# Using these changes: [0.00487852]
# Using these changes: [-0.00290589]
# Using these changes: [-0.00399618]
# Using these changes: [-0.00145864]
# Using these changes: [0.00149143]
# Using these changes: [-0.03767594]
# Using these changes: [0.00274766]
# Using these changes: [0.01615284]
# Using these changes: [-0.02209629]
# Using these changes: [0.00107807]
# Using these changes: [-0.01158855]
# Using these changes: [-0.01036365]
# Using these changes: [0.00248995]
# Using these changes: [-0.03424088]
# Using these changes: [0.01230092]
# Using these changes: [0.01649688]
# Using these changes: [0.00559298]
# Using these changes: [-0.03567505]
# Using these changes: [-0.00204838]
# Using these changes: [-0.00707905]
# Using these changes: [0.00366472]
# Using these changes: [-0.03074755]
# Using these changes: [-0.0525395]
# Using these changes: [0.01137145]
# Using these changes: [0.01173576]
# Using these changes: [0.00261269]
# Using these changes: [-0.03301559]
# Using these changes: [-0.12202901]
# Using these changes: [0.06607849]
# Using these changes: [-0.14844219]
# Using these changes: [0.0059082]
# Using these changes: [0.0491481]
# Using these changes: [-0.05173325]
# Using these changes: [0.00065994]
# Using these changes: [0.00043585]
# Using these changes: [0.00155849]
# Using these changes: [-0.00787045]
# Using these changes: [-0.02853605]
# Using these changes: [0.01869324]
# Using these changes: [-0.01108027]
# Using these changes: [-0.01006056]
# Using these changes: [-0.01342795]
# Using these changes: [0.00224464]
# Using these changes: [0.05066329]
# Using these changes: [-0.01717887]
# Using these changes: [0.01192299]
# Using these changes: [-0.00294919]
# Using these changes: [0.00512399]
# Using these changes: [-0.00707583]
# Using these changes: [-0.00639805]
# Using these changes: [-0.00104455]
# Using these changes: [0.00083281]
# Using these changes: [0.00108179]
# Using these changes: [0.00413629]
# Using these changes: [0.00343201]
# Using these changes: [0.00076557]
# Using these changes: [0.0023941]
# Using these changes: [0.15096205]
# Using these changes: [-0.01225109]
# Using these changes: [-0.01059636]
# Using these changes: [-0.00303161]
# Using these changes: [-0.01363421]
# Using these changes: [-0.01831291]
# Using these changes: [-0.04271485]
# Using these changes: [-0.04250841]
# Using these changes: [-0.0009897]
# Using these changes: [0.22891986]
# Using these changes: [-0.0257069]
# Using these changes: [-0.03051816]
# Using these changes: [0.03101932]
# Using these changes: [0.00945462]
# Using these changes: [0.01852387]
# Using these changes: [-0.01933746]
# Using these changes: [0.0344519]
# Using these changes: [-0.01096066]
# Using these changes: [0.00843908]
# Using these changes: [-0.01285068]
# Using these changes: [-0.03174492]
# Using these changes: [0.01628918]
# Using these changes: [-0.05357453]
# Using these changes: [-0.05623631]
# Using these changes: [-5.62554139e-05]
# Using these changes: [0.00758193]
# Using these changes: [0.0087018]
# Using these changes: [-0.02298062]
# Using these changes: [-0.00187731]
# Using these changes: [0.0048972]
# Using these changes: [0.00093532]
# Using these changes: [-0.00055045]
# Using these changes: [-0.00644046]
# Using these changes: [0.00211515]
# Using these changes: [0.01922606]
# Using these changes: [0.01838403]
# Using these changes: [0.00485271]
# Using these changes: [0.00765433]
# Using these changes: [-0.0075314]
# Using these changes: [-0.00752191]
# Using these changes: [0.03369274]
# Using these changes: [-0.01318268]
# Using these changes: [-0.01428152]
# Using these changes: [0.00376683]
# Using these changes: [-0.01462348]
# Using these changes: [0.01921988]
# Using these changes: [0.01323849]
# Using these changes: [0.03388142]
# Using these changes: [-0.01560122]
# Using these changes: [-0.01423176]
# Using these changes: [1.59134423e-05]
# Using these changes: [0.0423233]
# Using these changes: [0.00125693]
# Using these changes: [-0.00292384]
# Using these changes: [-0.00485125]
# Using these changes: [0.00585574]
# Using these changes: [-9.44825922e-05]
# Using these changes: [0.00350387]
# Using these changes: [-0.0115242]
# Using these changes: [0.00281966]
# Using these changes: [0.00078499]
# Using these changes: [-0.00054429]
# Using these changes: [-1.19247079e-05]
# Using these changes: [-0.00325394]
# Using these changes: [0.00164455]
# Using these changes: [0.00051334]
# Using these changes: [-0.00543557]
# Using these changes: [0.0022548]
# Using these changes: [0.00363173]
# Using these changes: [0.00390593]
# Using these changes: [0.00059022]
# Using these changes: [-0.01553938]
# Using these changes: [0.00964534]
# Using these changes: [-0.01717073]
# Using these changes: [-0.00149846]
# Using these changes: [0.00534648]
# Using these changes: [-0.02292003]
# Using these changes: [-0.0014653]
# Using these changes: [0.0129976]
# Using these changes: [0.00926491]
# Using these changes: [-0.01646771]
# Using these changes: [0.03233391]
# Using these changes: [0.00120334]
# Using these changes: [-0.00573022]
# Using these changes: [-0.16669655]
# Using these changes: [0.0953695]
# Using these changes: [0.0507242]
# Using these changes: [0.00449099]
# Using these changes: [0.01594238]
# Using these changes: [-0.19278342]
# Using these changes: [-0.00137435]
# Using these changes: [0.00363447]
# Using these changes: [-0.0018838]
# Using these changes: [-0.00030876]
# Using these changes: [0.00065951]
# Using these changes: [0.0320401]
# Using these changes: [-0.02963024]
# Using these changes: [0.06343049]
# Using these changes: [-0.00267676]
# Using these changes: [0.00078409]
# Using these changes: [-0.01032065]
# Using these changes: [0.00741479]
# Using these changes: [0.00700604]
# Using these changes: [-0.02036078]
# Using these changes: [0.0121137]
# Using these changes: [-0.00620568]
# Using these changes: [-0.00599864]
# Using these changes: [0.10162021]
# Using these changes: [0.00171613]
# Using these changes: [-0.03520088]
# Using these changes: [-0.04037543]
# Using these changes: [0.07772673]
# Using these changes: [0.0047478]
# Using these changes: [-0.0018119]
# Using these changes: [-0.00196531]
# Using these changes: [0.00713211]
# Using these changes: [-0.00172531]
# Using these changes: [0.00229495]
# Using these changes: [-0.00447872]
# Using these changes: [-0.00333695]
# Using these changes: [0.00999699]
# Using these changes: [-0.00565096]
# Using these changes: [0.009239]
# Using these changes: [0.21167041]
# Using these changes: [-0.14205615]
# Using these changes: [-0.08528535]
# Using these changes: [0.39886581]
# Using these changes: [-0.01952133]
# Using these changes: [-0.03340663]
# Using these changes: [-0.02743068]
# Using these changes: [0.11135341]
# Using these changes: [-0.00447555]
# Using these changes: [-0.00299932]
# Using these changes: [0.01003909]
# Using these changes: [-0.00133332]
# Using these changes: [0.00046641]
# Using these changes: [-0.00203061]
# Using these changes: [0.00248531]
# Using these changes: [0.0002011]
# Using these changes: [-0.00899461]
# Using these changes: [-0.00565079]
# Using these changes: [-0.01846122]
# Using these changes: [0.00434007]
# Using these changes: [0.00863776]
# Using these changes: [0.01853775]
# Using these changes: [-0.00099737]
# Using these changes: [-0.03231194]
# Using these changes: [0.00046286]
# Using these changes: [-0.00693154]
# Using these changes: [-0.03445535]
# Using these changes: [0.01240337]
# Using these changes: [0.01661018]
# Using these changes: [-0.02663735]
# Using these changes: [0.00169984]
# Using these changes: [-0.00541885]
# Using these changes: [0.00092597]
# Using these changes: [0.00104126]
# Using these changes: [-0.01422532]
# Using these changes: [0.00330377]
# Using these changes: [0.00737875]
# Using these changes: [0.00086598]
# Using these changes: [-0.00895973]
# Using these changes: [0.0013558]
# Using these changes: [-0.00861723]
# Using these changes: [-0.00059768]
# Using these changes: [-0.00128433]
# Using these changes: [0.00387262]
# Using these changes: [-0.00812576]
# Using these changes: [0.00924007]
# Using these changes: [-0.02847574]
# Using these changes: [-0.00554245]
# Using these changes: [-0.01425859]
# Using these changes: [0.0219197]
# Using these changes: [-0.03993726]
# Using these changes: [-0.0077487]
# Using these changes: [0.01744697]
# Using these changes: [-0.00350676]
# Using these changes: [0.00178566]
# Using these changes: [0.0154077]
# Using these changes: [0.00177339]
# Using these changes: [0.00436883]
# Using these changes: [-0.02075314]
# Using these changes: [0.01900409]
# Using these changes: [-0.00353839]
# Using these changes: [-0.03158827]
# Using these changes: [-0.00426051]
# Using these changes: [0.0828546]
# Using these changes: [0.00366875]
# Using these changes: [-0.00357453]
# Using these changes: [-0.00381702]
# Using these changes: [0.00830852]
# Using these changes: [0.00843268]
# Using these changes: [-0.00205045]
# Using these changes: [-0.0040854]
# Using these changes: [0.0081272]
# Using these changes: [0.00305194]
# Using these changes: [-0.00101775]
# Using these changes: [-0.00044677]
# Using these changes: [0.01861609]
# Using these changes: [-0.00663916]
# Using these changes: [-0.0064785]
# Using these changes: [-6.85943954e-06]
# Using these changes: [-0.00139572]
# Using these changes: [0.08086569]
# Using these changes: [-0.00080253]
# Using these changes: [-0.00093441]
# Using these changes: [-0.00291374]
# Using these changes: [-0.02976443]
# Using these changes: [0.04248456]
# Using these changes: [-0.00256478]
# Using these changes: [-0.0003981]
# Using these changes: [-0.0017042]
# Using these changes: [0.04881206]
# Using these changes: [-0.0280796]
# Using these changes: [0.0506332]
# Using these changes: [-0.0089993]
# Using these changes: [0.02894738]
# Using these changes: [-0.00589704]
# Using these changes: [0.03006526]
# Using these changes: [-0.00226001]
# Using these changes: [-0.0085861]
# Using these changes: [0.01505873]
# Using these changes: [-0.00536894]
# Using these changes: [0.00112442]
# Using these changes: [0.00432354]
# Using these changes: [-0.00954932]
# Using these changes: [0.00185056]
# Using these changes: [0.00179433]
# Using these changes: [-0.00425524]
# Using these changes: [0.02115693]
# Using these changes: [-0.00989214]
# Using these changes: [-0.03611191]
# Using these changes: [-0.00126433]
# Using these changes: [-0.0028265]
# Using these changes: [0.01417503]
# Using these changes: [0.01874808]
# Using these changes: [0.00986742]
# Using these changes: [-0.16863733]
# Using these changes: [0.02958017]
# Using these changes: [-3.72325934e-05]
# Using these changes: [0.07454236]
# Using these changes: [0.04602181]
# Using these changes: [0.00027068]
# Using these changes: [-0.16618101]
# Using these changes: [-0.0001042]
# Using these changes: [0.000442]
# Using these changes: [0.00076525]
# Using these changes: [0.00040142]
# Using these changes: [0.00077914]
# Using these changes: [-0.00371005]
# Using these changes: [0.00444132]
# Using these changes: [0.00162627]
# Using these changes: [-0.01076253]
# Using these changes: [0.04793864]
# Using these changes: [-0.05127299]
# Using these changes: [0.00519367]
# Using these changes: [0.00572449]
# Using these changes: [-0.00893232]
# Using these changes: [0.11447309]
# Using these changes: [0.00732635]
# Using these changes: [0.00286671]
# Using these changes: [-0.00117151]
# Using these changes: [0.00294672]
# Using these changes: [0.00092732]
# Using these changes: [-0.00420139]
# Using these changes: [-0.00049864]
# Using these changes: [-0.00053446]
# Using these changes: [-0.00135496]
# Using these changes: [-0.00130409]
# Using these changes: [0.00354193]
# Using these changes: [-0.10201215]
# Using these changes: [0.00272275]
# Using these changes: [0.05454663]
# Using these changes: [-0.0453305]
# Using these changes: [-0.00645257]
# Using these changes: [-0.00512685]
# Using these changes: [-0.0133552]
# Using these changes: [0.01294]
# Using these changes: [-0.01188428]
# Using these changes: [-0.00210863]
# Using these changes: [0.00214329]
# Using these changes: [0.00024978]
# Using these changes: [0.0003881]
# Using these changes: [0.00182841]
# Using these changes: [0.00149994]
# Using these changes: [-0.01003121]
# Using these changes: [-0.14815627]
# Using these changes: [0.00481857]
# Using these changes: [0.02696925]
# Using these changes: [0.07659017]
# Using these changes: [-0.10019897]
# Using these changes: [-0.00025598]
# Using these changes: [-0.00816367]
# Using these changes: [-0.01007038]
# Using these changes: [-0.00142483]
# Using these changes: [-0.00157052]
# Using these changes: [0.00168447]
# Using these changes: [0.00503076]
# Using these changes: [-0.00081118]
# Using these changes: [0.00329862]
# Using these changes: [-0.00084008]
# Using these changes: [-0.00564286]
# Using these changes: [-0.00244693]
# Using these changes: [0.01068659]
# Using these changes: [0.04817325]
# Using these changes: [-0.03560658]
# Using these changes: [-0.00073734]
# Using these changes: [-0.00098098]
# Using these changes: [-0.00210239]
# Using these changes: [-0.00209936]
# Using these changes: [0.08753273]
# Using these changes: [0.00798511]
# Using these changes: [0.08570407]
# Using these changes: [0.01172815]
# Using these changes: [0.01417059]
# Using these changes: [-0.00330626]
# Using these changes: [-0.00365712]
# Using these changes: [-0.00082478]
# Using these changes: [-0.02295717]
# Using these changes: [-0.02638914]
# Using these changes: [-0.01136716]
# Using these changes: [-0.02226675]
# Using these changes: [0.08132821]
# Using these changes: [-0.002046]
# Using these changes: [-0.00441355]
# Using these changes: [-0.07566391]
# Using these changes: [0.10299892]
# Using these changes: [-0.00151966]
# Using these changes: [-0.00433846]
# Using these changes: [-0.00464283]
# Using these changes: [-0.1806848]
# Using these changes: [0.00334434]
# Using these changes: [0.00722688]
# ...
# Using these changes: [0.0014522]
# Using these changes: [-0.00010678]
# Using these changes: [-0.00259644]
# Using these changes: [0.03771084]
# Using these changes: [0.04598542]
# Using these changes: [-0.00031138]
# Using these changes: [0.00069977]
# Using these changes: [-0.00626369]
# Using these changes: [-0.00354439]
# Using these changes: [0.00967122]
# Using these changes: [0.00080551]
# Using these changes: [-0.00763754]
# Using these changes: [-0.00466358]
# Using these changes: [-0.00115581]
# Using these changes: [-0.00382026]
# Using these changes: [-0.03385549]
# Using these changes: [-0.03397882]
# Using these changes: [0.00372353]
# Using these changes: [-0.00413669]
# Using these changes: [0.00617397]
# Using these changes: [0.0080916]
# Using these changes: [0.00805642]
# Using these changes: [0.0134731]
# Using these changes: [0.10559793]
# Using these changes: [-0.08706221]
# Using these changes: [0.19526691]
# Using these changes: [0.00032882]
# Using these changes: [-0.02604441]
# Using these changes: [-0.04169609]
# Using these changes: [-0.01090937]
# Using these changes: [-0.00294165]
# Using these changes: [-0.0313197]
# Using these changes: [-0.02746789]
# Using these changes: [0.00335604]
# Using these changes: [0.00642112]
# Using these changes: [0.01968497]
# Using these changes: [0.02171678]
# Using these changes: [0.0003833]
# Using these changes: [0.00087741]
# Using these changes: [0.00090604]
# Using these changes: [0.0036768]
# Using these changes: [0.00403414]
# Using these changes: [0.00126112]
# Using these changes: [0.00300983]
# Using these changes: [0.00309698]
# Using these changes: [0.00071121]
# Using these changes: [0.0014961]
# Using these changes: [0.02579062]
# Using these changes: [-0.02476515]
# Using these changes: [0.03043639]
# Using these changes: [0.00426578]
# Using these changes: [-0.00075257]
# Using these changes: [-0.02378754]
# Using these changes: [-0.00637445]
# Using these changes: [-0.00672278]
# Using these changes: [0.00431776]
# Using these changes: [-0.00999517]
# Using these changes: [0.00157821]
# Using these changes: [0.001075]
# Using these changes: [0.00112149]
# Using these changes: [0.00057925]
# Using these changes: [-0.00020307]
# Using these changes: [0.00307478]
# Using these changes: [0.00104695]
# Using these changes: [-0.00151913]
# Using these changes: [-0.00122452]
# Using these changes: [-0.00100473]
# Using these changes: [-0.00291753]
# Using these changes: [-0.00255134]
# Using these changes: [-0.00509528]
# Using these changes: [0.04293751]
# Using these changes: [-0.00143819]
# Using these changes: [0.08024699]
# Using these changes: [0.08047695]
# Using these changes: [0.00090617]
# Using these changes: [-0.00059932]
# Using these changes: [0.00110578]
# Using these changes: [-0.00032859]
# Using these changes: [0.02359259]
# Using these changes: [0.14254594]
# Using these changes: [-0.00060748]
# Using these changes: [0.00032296]
# Using these changes: [-0.00457702]
# Using these changes: [-0.00135357]
# Using these changes: [-0.02605337]
# Using these changes: [-0.00669682]
# Using these changes: [-0.08013123]
# Using these changes: [-0.10099589]
# Using these changes: [-0.00489157]
# Using these changes: [0.03585497]
# Using these changes: [0.02013042]
# Using these changes: [0.00469624]
# Using these changes: [0.00298552]
# Using these changes: [0.00183183]
# Using these changes: [0.00322013]
# Using these changes: [0.01157692]
# Using these changes: [0.01083424]
# Using these changes: [0.00516961]
# Using these changes: [0.01500235]
# Using these changes: [-0.00568389]
# Using these changes: [0.02693679]
# Using these changes: [-0.00390189]
# Using these changes: [-0.00401329]
# Using these changes: [-0.00286068]
# Using these changes: [-0.00389328]
# Using these changes: [-0.00274723]
# Using these changes: [0.02158281]
# Using these changes: [-0.00230186]
# Using these changes: [0.01143619]
# Using these changes: [0.02714107]
# Using these changes: [-0.00791333]
# Using these changes: [-0.01398782]
# Using these changes: [-0.03658897]
# Using these changes: [-0.01750565]
# Using these changes: [0.00370547]
# Using these changes: [0.00168829]
# Using these changes: [0.00143583]
# Using these changes: [-0.0001788]
# Using these changes: [0.00515555]
# Using these changes: [0.0078721]
# Using these changes: [0.08698266]
# Using these changes: [0.0264769]
# Using these changes: [-0.06400157]
# Using these changes: [-0.00546738]
# Using these changes: [-0.00444167]
# Using these changes: [0.00360724]
# Using these changes: [-0.00272109]
# Using these changes: [-0.00447399]
# Using these changes: [0.00701062]
# Using these changes: [0.00891489]
# Using these changes: [-0.00132146]
# Using these changes: [0.00591329]
# Using these changes: [0.00230528]
# Using these changes: [-0.00197036]
# Using these changes: [0.00252143]
# Using these changes: [-0.00460964]
# Using these changes: [0.00131602]
# Using these changes: [-0.01385222]
# Using these changes: [-0.04047512]
# Using these changes: [-0.02577865]
# Using these changes: [-0.03098326]
# Using these changes: [0.02878645]
# Using these changes: [0.0153147]
# Using these changes: [-0.01841681]
# Using these changes: [0.01598429]
# Using these changes: [-0.0006182]
# Using these changes: [0.00385274]
# Using these changes: [0.0031856]
# Using these changes: [-0.01051335]
# Using these changes: [0.00400593]
# Using these changes: [0.00482115]
# Using these changes: [0.0103464]
# Using these changes: [0.00138072]
# Using these changes: [0.00125737]
# Using these changes: [0.0028636]
# Using these changes: [0.00392769]
# Using these changes: [0.00139928]
# Using these changes: [0.00135283]
# Using these changes: [-0.02885939]
# Using these changes: [-0.01579053]
# Using these changes: [-0.00096287]
# Using these changes: [0.00932806]
# Using these changes: [0.01096582]
# Using these changes: [-0.00027511]
# Using these changes: [0.00031282]
# Using these changes: [0.00214698]
# Using these changes: [-0.00884788]
# Using these changes: [-0.00298589]
# Using these changes: [-0.02506907]
# Using these changes: [-0.02860008]
# Using these changes: [0.00780715]
# Using these changes: [-0.0287161]
# Using these changes: [-0.03164485]
# Using these changes: [0.0023269]
# Using these changes: [0.00071565]
# Using these changes: [0.01929756]
# Using these changes: [0.02447277]
# Using these changes: [0.00867964]
# Using these changes: [0.00462476]
# Using these changes: [0.00104941]
# Using these changes: [0.00048904]
# Using these changes: [-0.0004323]
# Using these changes: [0.00034923]
# Using these changes: [-0.00610261]
# Using these changes: [-0.00506817]
# Using these changes: [0.01287332]
# Using these changes: [0.01404286]
# Using these changes: [0.00462454]
# Using these changes: [0.00242176]
# Using these changes: [0.00068834]
# Using these changes: [0.02592941]
# Using these changes: [0.02989867]
# Using these changes: [-0.0143347]
# Using these changes: [-0.00774461]
# Using these changes: [0.01118167]
# Using these changes: [-9.82311777e-05]
# Using these changes: [0.00263882]
# Using these changes: [0.01017558]
# Using these changes: [0.00185161]
# Using these changes: [0.00144778]
# Using these changes: [0.00043864]
# Using these changes: [0.00160296]
# Using these changes: [0.0013408]
# Using these changes: [0.00155104]
# Using these changes: [-0.00204145]
# Using these changes: [0.0003964]
# Using these changes: [0.0016042]
# Using these changes: [-0.00403845]
# Using these changes: [-0.00303892]
# Using these changes: [0.00028564]
# Using these changes: [0.00598576]
# Using these changes: [0.00666518]
# Using these changes: [0.00084242]
# Using these changes: [0.0024957]
# Using these changes: [0.00299888]
# Using these changes: [0.00892004]
# Using these changes: [0.00891781]
# Using these changes: [-0.00015246]
# Using these changes: [4.93940954e-05]
# Using these changes: [-0.00476629]
# Using these changes: [-0.00496792]
# Using these changes: [0.00048117]
# Using these changes: [0.00427603]
# Using these changes: [0.01090069]
# Using these changes: [0.00033935]
# Using these changes: [0.00033923]
# Using these changes: [0.00043792]
# Using these changes: [-0.00034313]
# Using these changes: [0.00131351]
# Using these changes: [0.01418689]
# Using these changes: [0.01525761]
# Using these changes: [0.0018179]
# Using these changes: [0.00012014]
# Using these changes: [0.00031022]
# Using these changes: [0.00365127]
# Using these changes: [0.00431185]
# Using these changes: [0.00203279]
# Using these changes: [-0.00127909]
# Using these changes: [0.00593429]
# Using these changes: [-0.00039985]
# Using these changes: [9.38361264e-05]
# Using these changes: [-0.00756449]
# Using these changes: [0.00412723]
# Using these changes: [-0.00433014]
# Using these changes: [-0.00624718]
# Using these changes: [-0.0066886]
# Using these changes: [-0.00014882]
# Using these changes: [-0.01173569]
# Using these changes: [-0.01014009]
# Using these changes: [-0.08377902]
# Using these changes: [-0.08268428]
# Using these changes: [-0.01768658]
# Using these changes: [0.01526866]
# Using these changes: [-0.03101013]
# Using these changes: [-0.00551144]
# Using these changes: [0.01396612]
# Using these changes: [-0.01615005]
# Using these changes: [0.03666963]
# Using these changes: [0.00427025]
# Using these changes: [0.00899127]
# Using these changes: [0.01685073]
# Using these changes: [0.01522484]
# Using these changes: [0.01049423]
# Using these changes: [0.01340057]
# Using these changes: [0.0086611]
# Using these changes: [0.00690792]
# Using these changes: [0.00426907]
# Using these changes: [0.00028555]
# Using these changes: [0.00051444]
# Using these changes: [-0.00161583]
# Using these changes: [-0.00393465]
# Using these changes: [-0.01967475]
# Using these changes: [-0.01897039]
# Using these changes: [-0.00599259]
# Using these changes: [-0.00540691]
# Using these changes: [0.0053121]
# Using these changes: [0.00483243]
# Using these changes: [-0.04681733]
# Using these changes: [0.02315046]
# Using these changes: [-0.00815038]
# Using these changes: [-0.01233496]
# Using these changes: [0.0357651]
# Using these changes: [0.01165386]
# Using these changes: [0.00034474]
# Using these changes: [0.0201433]
# Using these changes: [0.02072328]
# Using these changes: [-0.00068457]
# Using these changes: [-0.01039793]
# Using these changes: [0.01074213]
# Using these changes: [0.02322049]
# Using these changes: [0.00301203]
# Using these changes: [0.00078759]
# Using these changes: [0.00201921]
# Using these changes: [0.0002184]
# Using these changes: [-0.00013539]
# Using these changes: [0.00045157]
# Using these changes: [0.00045136]
# Using these changes: [-0.00748377]
# Using these changes: [-0.00822503]
# Using these changes: [-0.00339413]
# Using these changes: [-0.00300372]
# Using these changes: [-0.00130574]
# Using these changes: [-0.0035243]
# Using these changes: [0.01810904]
# Using these changes: [0.02038515]
# Using these changes: [-0.03327734]
# Using these changes: [0.01592735]
# Using these changes: [-0.01101075]
# Using these changes: [0.0005044]
# Using these changes: [0.0034654]
# Using these changes: [0.00574101]
# Using these changes: [0.00260828]
# Using these changes: [0.0041215]
# Using these changes: [-0.00395532]
# Using these changes: [0.0003366]
# Using these changes: [-0.00249185]
# Using these changes: [-0.00796015]
# Using these changes: [0.00072051]
# Using these changes: [-0.01223071]
# Using these changes: [-0.01223559]
# Using these changes: [0.00044589]
# Using these changes: [-0.00406471]
# Using these changes: [-0.00495905]
# Using these changes: [0.0066336]
# Using these changes: [0.00790041]
# Using these changes: [0.01225465]
# Using these changes: [-0.00723704]
# Using these changes: [0.01023297]
# Using these changes: [-0.00514579]
# Using these changes: [0.00088571]
# Using these changes: [-0.00022324]
# Using these changes: [0.00239269]
# Using these changes: [0.00285056]
# Using these changes: [0.0125115]
# Using these changes: [0.01072642]
# Using these changes: [-0.00151913]
# Using these changes: [-0.002078]
# Using these changes: [-0.02607996]
# Using these changes: [-0.0288108]
# Using these changes: [-0.00754106]
# Using these changes: [-0.0062141]
# Using these changes: [-0.00759529]
# Using these changes: [-0.00184284]
# Using these changes: [0.0061481]
# Using these changes: [-0.00638764]
# Using these changes: [-0.00347087]
# Using these changes: [0.00998108]
# Using these changes: [-0.00092159]
# Using these changes: [0.00125391]
# Using these changes: [-0.00252042]
# Using these changes: [-0.01019555]
# Using these changes: [-0.0094339]
# Using these changes: [0.00209481]
# Using these changes: [-0.05612375]
# Using these changes: [-0.05637953]
# Using these changes: [-0.00248958]
# Using these changes: [0.00272587]
# Using these changes: [0.00482537]
# Using these changes: [0.00613453]
# Using these changes: [0.00037866]
# Using these changes: [0.00534175]
# Using these changes: [0.01296305]
# Using these changes: [-0.00040177]
# Using these changes: [0.00135492]
# Using these changes: [-0.00149005]
# Using these changes: [-0.00386619]
# Using these changes: [-0.00329178]
# Using these changes: [-0.00189789]
# Using these changes: [0.00148462]
# Using these changes: [0.00148655]
# Using these changes: [0.00066306]
# Using these changes: [0.01818063]
# Using these changes: [0.01965608]
# Using these changes: [-0.0004794]
# Using these changes: [0.00581826]
# Using these changes: [0.00074442]
# Using these changes: [0.01102205]
# Using these changes: [0.0082517]
# Using these changes: [0.03833081]
# Using these changes: [0.05632255]
# Using these changes: [-0.00725281]
# Using these changes: [0.01949652]
# Using these changes: [-0.00252953]
# Using these changes: [-0.0024259]
# Using these changes: [-0.00232256]
# Using these changes: [-0.00231992]
# Using these changes: [0.01211706]
# Using these changes: [-0.01767577]
# Using these changes: [-0.01952603]
# Using these changes: [-0.00097882]
# Using these changes: [0.0052991]
# Using these changes: [0.00613276]
# Using these changes: [0.0017088]
# Using these changes: [0.00160742]
# Using these changes: [0.00247219]
# Using these changes: [0.01384022]
# Using these changes: [0.02566033]
# Using these changes: [0.01159912]
# Using these changes: [-0.0012437]
# Using these changes: [0.00718222]
# Using these changes: [-0.00580122]
# Using these changes: [0.02536889]
# Using these changes: [-0.00187783]
# Using these changes: [-0.00624777]
# Using these changes: [0.0095535]
# Using these changes: [0.000587]
# Using these changes: [0.00900517]
# Using these changes: [-0.00214694]
# Using these changes: [-0.01836433]
# Using these changes: [0.00137785]
# Using these changes: [0.00792331]
# Using these changes: [-0.00463924]
# Using these changes: [-0.00717675]
# Using these changes: [0.00814132]
# Using these changes: [0.02003119]
# Using these changes: [0.0340578]
# Using these changes: [0.04611654]
# Using these changes: [-0.03271214]
# Using these changes: [0.00053393]
# Using these changes: [0.00237872]
# Using these changes: [0.00223342]
# Using these changes: [-0.00446453]
# Using these changes: [-0.00431916]
# Using these changes: [0.00021223]
# Using these changes: [0.00270326]
# Using these changes: [-0.00514583]
# Using these changes: [0.00973672]
# Using these changes: [-0.02027868]
# Using these changes: [0.00138469]
# Using these changes: [0.0006372]
# Using these changes: [0.00268942]
# Using these changes: [0.0020568]
# Using these changes: [0.00097595]
# Using these changes: [0.00139683]
# Using these changes: [-0.00114379]
# Using these changes: [-0.03443298]
# Using these changes: [0.0052875]
# Using these changes: [-0.0140435]
# Using these changes: [-0.01395282]
# Using these changes: [-0.02119684]
# Using these changes: [-0.00019073]
# Using these changes: [0.02517644]
# Using these changes: [0.02468285]
# Using these changes: [0.02301321]
# Using these changes: [0.03614627]
# Using these changes: [0.01033465]
# Using these changes: [0.01497878]
# Using these changes: [-0.00091883]
# Using these changes: [-0.01353027]
# Using these changes: [0.00857034]
# Using these changes: [-0.00195094]
# Using these changes: [0.00461881]
# Using these changes: [0.00374913]
# Using these changes: [0.00522489]
# Using these changes: [-0.044338]
# Using these changes: [-0.00876684]
# Using these changes: [0.00772208]
# Using these changes: [-0.00233353]
# Using these changes: [0.01178842]
# Using these changes: [-0.01181778]
# Using these changes: [0.02856758]
# Using these changes: [0.01018772]
# Using these changes: [0.00278555]
# Using these changes: [0.00713266]
# Using these changes: [-0.00136506]
# Using these changes: [-0.00211238]

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, 
               input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))  # Output layer - predicting the price change

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Make predictions
y_pred = model.predict(X_test)

# Inverse transform to get real values
y_pred_actual = y_scaler.inverse_transform(y_pred)
y_test_actual = y_scaler.inverse_transform(y_test)

# Evaluate the model
mse = np.mean((y_pred_actual - y_test_actual) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# Epoch 1/100
# c:\Users\matth\Uni work\Year 3\Spring Semester\CM3203 - One Semester Individual Project\Project Environment\CM3202-Venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0184 - val_loss: 0.0015
# Epoch 2/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 3/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 4/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 5/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 6/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 7/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 8/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 9/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 10/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 11/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 12/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 13/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 14/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 15/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 16/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 17/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 18/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 19/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 20/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 21/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 22/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 23/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 24/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 25/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 26/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 27/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 28/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 29/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 30/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 31/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 32/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 33/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 34/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 35/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 36/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 37/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 38/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 39/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 40/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 41/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 42/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 43/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 44/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 45/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 46/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 47/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 48/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 49/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 50/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 51/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 52/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 53/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 54/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 55/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 56/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 57/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 58/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 59/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 60/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 61/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 62/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 63/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 64/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 65/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 66/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 67/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 68/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 69/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 70/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 71/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 72/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 73/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 74/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 75/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 76/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 77/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 78/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 79/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 80/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 81/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 82/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 83/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 84/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 85/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 86/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 87/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 88/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 89/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 90/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 91/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 92/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 93/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 94/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 95/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 96/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 97/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 98/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 99/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 100/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error: 0.0006556737409465753

# %%
# Modified MAPE calculation with safeguards
def calculate_mape(y_true, y_pred):
    # Filter out zeros in actual values to avoid division by zero
    mask = y_true.flatten() != 0
    if not np.any(mask):  # If all values are zero
        return "Cannot calculate MAPE: All actual values are zero"
    
    # Calculate MAPE only for non-zero actual values
    percentage_errors = np.abs((y_true.flatten()[mask] - y_pred.flatten()[mask]) / y_true.flatten()[mask]) * 100
    
    # Remove infinite or extremely large values (optional)
    filtered_errors = percentage_errors[~np.isinf(percentage_errors) & (percentage_errors < 1000)]
    
    if len(filtered_errors) == 0:
        return "Cannot calculate meaningful MAPE: Errors too large or undefined"
    
    return np.mean(filtered_errors)

# Using the function
mape_value = calculate_mape(y_test_actual, y_pred_actual)
print(f"Mean Absolute Percentage Error: {mape_value}%")
# Out:
# Mean Absolute Percentage Error: 163.22716737125634%

# %%
# Plot actual vs predicted

def plot_actual_vs_predicted(y_test_actual, y_pred_actual):
    """
    Create comprehensive plots comparing actual vs predicted price changes.
    
    Parameters:
    y_test_actual - numpy array of actual price changes
    y_pred_actual - numpy array of predicted price changes
    """
    # Ensure inputs are flattened
    y_test_actual = y_test_actual.flatten()
    y_pred_actual = y_pred_actual.flatten()
    
    # Create a figure with 2x2 subplots
    fig, axs = plt.subplots(2, 2, figsize=(16, 12))
    
    # 1. Time series plot of actual vs predicted values
    axs[0, 0].plot(y_test_actual, label='Actual', linewidth=2)
    axs[0, 0].plot(y_pred_actual, label='Predicted', linewidth=2, linestyle='--')
    axs[0, 0].set_title('Actual vs Predicted Price Changes Over Time', fontsize=14)
    axs[0, 0].set_xlabel('Sample Index', fontsize=12)
    axs[0, 0].set_ylabel('Price Change', fontsize=12)
    axs[0, 0].legend(fontsize=12)
    axs[0, 0].grid(True)
    
    # 2. Scatter plot of actual vs predicted with diagonal line
    axs[0, 1].scatter(y_test_actual, y_pred_actual, alpha=0.6)
    
    # Add diagonal line (perfect predictions)
    min_val = min(y_test_actual.min(), y_pred_actual.min())
    max_val = max(y_test_actual.max(), y_pred_actual.max())
    axs[0, 1].plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    
    axs[0, 1].set_title('Scatter Plot of Actual vs Predicted Values', fontsize=14)
    axs[0, 1].set_xlabel('Actual Price Change', fontsize=12)
    axs[0, 1].set_ylabel('Predicted Price Change', fontsize=12)
    axs[0, 1].grid(True)
    
    # 3. Histogram of errors
    errors = y_test_actual - y_pred_actual
    axs[1, 0].hist(errors, bins=30, alpha=0.7, color='blue')
    axs[1, 0].axvline(x=0, color='r', linestyle='--', linewidth=2)
    axs[1, 0].set_title('Distribution of Prediction Errors', fontsize=14)
    axs[1, 0].set_xlabel('Error (Actual - Predicted)', fontsize=12)
    axs[1, 0].set_ylabel('Frequency', fontsize=12)
    axs[1, 0].grid(True)
    
    # 4. Directional accuracy visualization
    correct_direction = np.sign(y_test_actual) == np.sign(y_pred_actual)
    axs[1, 1].bar(['Correct Direction', 'Wrong Direction'], 
                 [np.sum(correct_direction), np.sum(~correct_direction)],
                 color=['green', 'red'])
    
    directional_accuracy = np.mean(correct_direction) * 100
    axs[1, 1].set_title(f'Directional Accuracy: {directional_accuracy:.2f}%', fontsize=14)
    axs[1, 1].set_ylabel('Count', fontsize=12)
    axs[1, 1].grid(True, axis='y')
    
    plt.tight_layout()
    plt.show()

plot_actual_vs_predicted(y_test_actual, y_pred_actual)

# %%
def plot_top_predicted_price_changes(cleaned_df, y_pred_actual, percentage=10):
    """
    Plot the actual price chart and highlight where the model predicts the largest price changes.
    
    Parameters:
    cleaned_df - The original DataFrame with token prices
    y_pred_actual - numpy array of predicted price changes (percentage)
    percentage - Top percentage of price changes to highlight (default: 10%)
    """
    import matplotlib.dates as mdates
    from matplotlib.patches import Rectangle
    
    # Flatten the predictions if needed
    y_pred_actual = y_pred_actual.flatten()
    
    # Determine where the test predictions start in the cleaned dataframe
    test_start = len(cleaned_df) - len(y_pred_actual)
    
    # Get the actual token prices for the test period
    actual_prices = cleaned_df['token_price'].values[test_start:]
    
    # Get the timestamps or indices
    if 'block_time' in cleaned_df.columns:
        time_axis = cleaned_df['block_time'].values[test_start:]
    elif 'slot' in cleaned_df.columns:
        time_axis = cleaned_df['slot'].values[test_start:]
    else:
        time_axis = np.arange(len(actual_prices))
    
    # Find the indices of the top positive and negative predicted changes
    num_to_highlight = int(len(y_pred_actual) * percentage / 100)
    
    # Sort by absolute value to get largest changes in either direction
    sorted_indices = np.argsort(np.abs(y_pred_actual))[::-1]
    top_indices = sorted_indices[:num_to_highlight]
    
    # Separate positive and negative changes
    positive_indices = [i for i in top_indices if y_pred_actual[i] > 0]
    negative_indices = [i for i in top_indices if y_pred_actual[i] < 0]
    
    # Create the plot
    plt.figure(figsize=(14, 7))
    
    # Plot the actual price line
    plt.plot(time_axis, actual_prices, label='Actual Price', color='blue', linewidth=2)
    
    # Plot markers for top positive predicted changes
    if positive_indices:
        plt.scatter(
            time_axis[positive_indices], 
            actual_prices[positive_indices], 
            color='green', 
            s=100, 
            marker='^', 
            label=f'Top {percentage}% Positive Predicted Changes'
        )
        
        # Annotate positive changes with the predicted percentage
        for idx in positive_indices:
            plt.annotate(
                f"+{y_pred_actual[idx]:.2f}%", 
                (time_axis[idx], actual_prices[idx]),
                xytext=(5, 10),
                textcoords='offset points',
                color='darkgreen',
                fontweight='bold'
            )
    
    # Plot markers for top negative predicted changes
    if negative_indices:
        plt.scatter(
            time_axis[negative_indices], 
            actual_prices[negative_indices], 
            color='red', 
            s=100, 
            marker='v', 
            label=f'Top {percentage}% Negative Predicted Changes'
        )
        
        # Annotate negative changes with the predicted percentage
        for idx in negative_indices:
            plt.annotate(
                f"{y_pred_actual[idx]:.2f}%", 
                (time_axis[idx], actual_prices[idx]),
                xytext=(5, -20),
                textcoords='offset points',
                color='darkred',
                fontweight='bold'
            )
    
    # Add titles and labels
    plt.title(f'Token Price with Top {percentage}% Predicted Price Changes', fontsize=16)
    plt.xlabel('Time', fontsize=14)
    plt.ylabel('Token Price', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # Format x-axis if using datetime
    if hasattr(time_axis[0], 'dtype') and np.issubdtype(time_axis[0].dtype, np.datetime64):
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
        plt.gcf().autofmt_xdate()
    
    plt.tight_layout()
    plt.show()
    
    # Also create a second plot showing the distribution of predicted changes
    plt.figure(figsize=(12, 5))
    
    # Plot histogram of all predicted changes
    plt.hist(y_pred_actual, bins=30, alpha=0.5, color='blue', label='All Predictions')
    
    # Highlight thresholds used for top changes
    if len(y_pred_actual) > 0:
        # Find thresholds
        sorted_positive = np.sort(y_pred_actual[y_pred_actual > 0])
        sorted_negative = np.sort(y_pred_actual[y_pred_actual < 0])
        
        positive_threshold = sorted_positive[-min(num_to_highlight, len(sorted_positive))] if len(sorted_positive) > 0 else 0
        negative_threshold = sorted_negative[min(num_to_highlight, len(sorted_negative))-1] if len(sorted_negative) > 0 else 0
        
        # Plot vertical lines at thresholds
        if positive_threshold > 0:
            plt.axvline(x=positive_threshold, color='green', linestyle='--', 
                       label=f'Positive Threshold: {positive_threshold:.2f}%')
        
        if negative_threshold < 0:
            plt.axvline(x=negative_threshold, color='red', linestyle='--',
                       label=f'Negative Threshold: {negative_threshold:.2f}%')
    
    plt.title('Distribution of Predicted Price Changes', fontsize=16)
    plt.xlabel('Predicted Change (%)', fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# Example usage:
plot_top_predicted_price_changes(cleaned_df, y_pred_actual, percentage=5)
