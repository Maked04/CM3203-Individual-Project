# %%
## Imports 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import LSTM, Dense, Dropout # type: ignore

from src.data_processing.lstm_data_preprocessing import get_token_features, get_sliding_windows
from src.data_processing.loader import load_token_data
from src.data_processing.processor import remove_price_anomalies
from src.visualisation.price_plotter import plot_token_price

# %%
# Load and prep data

token_address = "WUb891xiehvvaDURF1r5ZBcbKULPQHcSnNtLfywpump"
sequence_length = 30
# Load data
df = load_token_data(token_address)
    
# Clean data for price features
cleaned_df = remove_price_anomalies(df)

feature_matrix = get_token_features(token_address, relative_time=True)

X, y = get_sliding_windows(feature_matrix, sequence_length=sequence_length, prediction_horizon=5)

# Normalize the features (important for LSTM models)
# Apply scaling only to the features (not the targets)
feature_scaler = MinMaxScaler(feature_range=(0, 1))

# Reshape X to 2D for scaling then back to 3D
num_samples, time_steps, features = X.shape
X_reshaped = X.reshape(num_samples * time_steps, features)
X_scaled = feature_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(num_samples, time_steps, features)

# Scale the target variable y
y_scaler = MinMaxScaler(feature_range=(0, 1))
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, shuffle=False
)
# Out:
# Using these changes: [-0.0017366  -0.04686528  0.02488679 -0.04808246 -0.00341265]
# We get cumulative change of:  -0.07489712380981972
# vs adding way
# We get cumulative change of:  -0.07521020483707408
# Using these changes: [-0.04686528  0.02488679 -0.04808246 -0.00341265  0.01414904]
# We get cumulative change of:  -0.060175707320473504
# vs adding way
# We get cumulative change of:  -0.05932456481084336
# Using these changes: [ 0.02488679 -0.04808246 -0.00341265  0.01414904 -0.02478457]
# We get cumulative change of:  -0.03840334683672075
# vs adding way
# We get cumulative change of:  -0.03724384950733295
# Using these changes: [-0.04808246 -0.00341265  0.01414904 -0.02478457  0.00174647]
# We get cumulative change of:  -0.060114674774350174
# vs adding way
# We get cumulative change of:  -0.060384168396342086
# Using these changes: [-0.00341265  0.01414904 -0.02478457  0.00174647  0.00839018]
# We get cumulative change of:  -0.004355843605755361
# vs adding way
# We get cumulative change of:  -0.003911524433247271
# Using these changes: [ 0.01414904 -0.02478457  0.00174647  0.00839018 -0.01387862]
# We get cumulative change of:  -0.014811909563797299
# vs adding way
# We get cumulative change of:  -0.014377495626062164
# Using these changes: [-0.02478457  0.00174647  0.00839018 -0.01387862 -0.00841897]
# We get cumulative change of:  -0.03673544931887485
# vs adding way
# We get cumulative change of:  -0.03694550777906158
# Using these changes: [ 0.00174647  0.00839018 -0.01387862 -0.00841897 -0.0103051 ]
# We get cumulative change of:  -0.0224334242170795
# vs adding way
# We get cumulative change of:  -0.022466042528754282
# Using these changes: [ 0.00839018 -0.01387862 -0.00841897 -0.0103051  -0.0222205 ]
# We get cumulative change of:  -0.04582188422683864
# vs adding way
# We get cumulative change of:  -0.04643301097887054
# Using these changes: [-0.01387862 -0.00841897 -0.0103051  -0.0222205  -0.02715198]
# We get cumulative change of:  -0.07945326032221323
# vs adding way
# We get cumulative change of:  -0.08197516912516722
# Using these changes: [-0.00841897 -0.0103051  -0.0222205  -0.02715198 -0.02657953]
# We get cumulative change of:  -0.09130959230503666
# vs adding way
# We get cumulative change of:  -0.09467608036887931
# Using these changes: [-0.0103051  -0.0222205  -0.02715198 -0.02657953  0.01422241]
# We get cumulative change of:  -0.07056090490559797
# vs adding way
# We get cumulative change of:  -0.0720347004163413
# Using these changes: [-0.0222205  -0.02715198 -0.02657953  0.01422241 -0.02639446]
# We get cumulative change of:  -0.08567068813518108
# vs adding way
# We get cumulative change of:  -0.08812405521122835
# Using these changes: [-0.02715198 -0.02657953  0.01422241 -0.02639446 -0.00443817]
# We get cumulative change of:  -0.06904229363441561
# vs adding way
# We get cumulative change of:  -0.0703417276688959
# Using these changes: [-0.02657953  0.01422241 -0.02639446 -0.00443817 -0.0211079 ]
# We get cumulative change of:  -0.0632584705057938
# vs adding way
# We get cumulative change of:  -0.0642976497612946
# Using these changes: [ 0.01422241 -0.02639446 -0.00443817 -0.0211079  -0.0038701 ]
# We get cumulative change of:  -0.04140474224610868
# vs adding way
# We get cumulative change of:  -0.041588219572288754
# Using these changes: [-0.02639446 -0.00443817 -0.0211079  -0.0038701   0.00075792]
# We get cumulative change of:  -0.05413074053450906
# vs adding way
# We get cumulative change of:  -0.05505270578003785
# Using these changes: [-0.00443817 -0.0211079  -0.0038701   0.00075792 -0.00063704]
# We get cumulative change of:  -0.029107107509040553
# vs adding way
# We get cumulative change of:  -0.029295289982117945
# Using these changes: [-0.0211079  -0.0038701   0.00075792 -0.00063704  0.08632792]
# We get cumulative change of:  0.0594098978642954
# vs adding way
# We get cumulative change of:  0.06147080023837492
# Using these changes: [-0.0038701   0.00075792 -0.00063704  0.08632792 -0.03976353]
# We get cumulative change of:  0.03921976614452216
# vs adding way
# We get cumulative change of:  0.04281516889950321
# Using these changes: [ 0.00075792 -0.00063704  0.08632792 -0.03976353  0.08822436]
# We get cumulative change of:  0.1352979823741507
# vs adding way
# We get cumulative change of:  0.13490962935631257
# Using these changes: [-0.00063704  0.08632792 -0.03976353  0.08822436 -0.0240303 ]
# We get cumulative change of:  0.10717727464170168
# vs adding way
# We get cumulative change of:  0.11012140506329093
# Using these changes: [ 0.08632792 -0.03976353  0.08822436 -0.0240303   0.03128288]
# We get cumulative change of:  0.1425408091432787
# vs adding way
# We get cumulative change of:  0.14204132183182594
# Using these changes: [-0.03976353  0.08822436 -0.0240303   0.03128288  0.02723776]
# We get cumulative change of:  0.08039298711405074
# vs adding way
# We get cumulative change of:  0.08295116616817189
# Using these changes: [ 0.08822436 -0.0240303   0.03128288  0.02723776 -0.01350466]
# We get cumulative change of:  0.10993768327499209
# vs adding way
# We get cumulative change of:  0.1092100322705748
# Using these changes: [-0.0240303   0.03128288  0.02723776 -0.01350466  0.01797297]
# We get cumulative change of:  0.038284573796953936
# vs adding way
# We get cumulative change of:  0.038958647699029236
# Using these changes: [ 0.03128288  0.02723776 -0.01350466  0.01797297  0.02967038]
# We get cumulative change of:  0.09541400323287053
# vs adding way
# We get cumulative change of:  0.09265933185210473
# Using these changes: [ 0.02723776 -0.01350466  0.01797297  0.02967038 -0.03225183]
# We get cumulative change of:  0.02792834307088632
# vs adding way
# We get cumulative change of:  0.0291246267719234
# Using these changes: [-0.01350466  0.01797297  0.02967038 -0.03225183  0.07020279]
# We get cumulative change of:  0.07092225250484896
# vs adding way
# We get cumulative change of:  0.07208965222654906
# Using these changes: [ 0.01797297  0.02967038 -0.03225183  0.07020279  0.00135828]
# We get cumulative change of:  0.0870572009109658
# vs adding way
# We get cumulative change of:  0.08695259053444215
# Using these changes: [ 0.02967038 -0.03225183  0.07020279  0.00135828  0.00120234]
# We get cumulative change of:  0.06914844103724649
# vs adding way
# We get cumulative change of:  0.07018196106045482
# Using these changes: [-0.03225183  0.07020279  0.00135828  0.00120234  0.0055381 ]
# We get cumulative change of:  0.04409091491132555
# vs adding way
# We get cumulative change of:  0.04604967830512141
# Using these changes: [0.07020279 0.00135828 0.00120234 0.0055381  0.00628359]
# We get cumulative change of:  0.08566628124304243
# vs adding way
# We get cumulative change of:  0.08458510094742655
# Using these changes: [0.00135828 0.00120234 0.0055381  0.00628359 0.03415338]
# We get cumulative change of:  0.049095991244524795
# vs adding way
# We get cumulative change of:  0.04853569325020568
# Using these changes: [ 0.00120234  0.0055381   0.00628359  0.03415338 -0.00593073]
# We get cumulative change of:  0.04145949553917894
# vs adding way
# We get cumulative change of:  0.04124668610916704
# Using these changes: [ 0.0055381   0.00628359  0.03415338 -0.00593073 -0.01516425]
# We get cumulative change of:  0.02443481992669816
# vs adding way
# We get cumulative change of:  0.024880091732712994
# Using these changes: [ 0.00628359  0.03415338 -0.00593073 -0.01516425  0.06017508]
# We get cumulative change of:  0.08009857455909075
# vs adding way
# We get cumulative change of:  0.07951707293987087
# Using these changes: [ 0.03415338 -0.00593073 -0.01516425  0.06017508  0.44760067]
# We get cumulative change of:  0.5537880471367478
# vs adding way
# We get cumulative change of:  0.520834148503811
# Using these changes: [-0.00593073 -0.01516425  0.06017508  0.44760067 -0.10657993]
# We get cumulative change of:  0.3423399747060425
# vs adding way
# We get cumulative change of:  0.3801008356587302
# Using these changes: [-0.01516425  0.06017508  0.44760067 -0.10657993 -0.13591405]
# We get cumulative change of:  0.16681719081395707
# vs adding way
# We get cumulative change of:  0.2501175164661147
# Using these changes: [ 0.06017508  0.44760067 -0.10657993 -0.13591405  0.42915168]
# We get cumulative change of:  0.6932353925456185
# vs adding way
# We get cumulative change of:  0.694433445483981
# Using these changes: [ 0.44760067 -0.10657993 -0.13591405  0.42915168 -0.09404129]
# We get cumulative change of:  0.44693210436287045
# vs adding way
# We get cumulative change of:  0.5402170799384259
# Using these changes: [-0.10657993 -0.13591405  0.42915168 -0.09404129  0.08027482]
# We get cumulative change of:  0.0797759017044779
# vs adding way
# We get cumulative change of:  0.17289123051638378
# Using these changes: [-0.13591405  0.42915168 -0.09404129  0.08027482 -0.06237712]
# We get cumulative change of:  0.13319883894996054
# vs adding way
# We get cumulative change of:  0.21709403615506484
# Using these changes: [ 0.42915168 -0.09404129  0.08027482 -0.06237712 -0.01189084]
# We get cumulative change of:  0.29584812189199794
# vs adding way
# We get cumulative change of:  0.34111724835079316
# Using these changes: [-0.09404129  0.08027482 -0.06237712 -0.01189084  0.0787978 ]
# We get cumulative change of:  -0.02182664041293192
# vs adding way
# We get cumulative change of:  -0.009236633425234952
# Using these changes: [ 0.08027482 -0.06237712 -0.01189084  0.0787978  -0.00311674]
# We get cumulative change of:  0.07634556313662855
# vs adding way
# We get cumulative change of:  0.0816879071487383
# Using these changes: [-0.06237712 -0.01189084  0.0787978  -0.00311674 -0.01530806]
# We get cumulative change of:  -0.01888964975509666
# vs adding way
# We get cumulative change of:  -0.013894966854328783
# Using these changes: [-0.01189084  0.0787978  -0.00311674 -0.01530806 -0.03324134]
# We get cumulative change of:  0.011597464505368471
# vs adding way
# We get cumulative change of:  0.01524081356622653
# Using these changes: [ 0.0787978  -0.00311674 -0.01530806 -0.03324134 -0.00854377]
# We get cumulative change of:  0.015024093686296869
# vs adding way
# We get cumulative change of:  0.018587879771628013
# Using these changes: [-0.00311674 -0.01530806 -0.03324134 -0.00854377  0.07398343]
# We get cumulative change of:  0.010494327072547716
# vs adding way
# We get cumulative change of:  0.013773509086231317
# Using these changes: [-0.01530806 -0.03324134 -0.00854377  0.07398343 -0.00454371]
# We get cumulative change of:  0.009047882766269222
# vs adding way
# We get cumulative change of:  0.012346547974607436
# Using these changes: [-0.03324134 -0.00854377  0.07398343 -0.00454371 -0.11499746]
# We get cumulative change of:  -0.09310729570686072
# vs adding way
# We get cumulative change of:  -0.08734285534758002
# Using these changes: [-0.00854377  0.07398343 -0.00454371 -0.11499746 -0.03321509]
# We get cumulative change of:  -0.09308266618140959
# vs adding way
# We get cumulative change of:  -0.08731659997381447
# Using these changes: [ 0.07398343 -0.00454371 -0.11499746 -0.03321509  0.08060319]
# We get cumulative change of:  -0.01153703543487139
# vs adding way
# We get cumulative change of:  0.0018303602123179719
# Using these changes: [-0.00454371 -0.11499746 -0.03321509  0.08060319  0.01163335]
# We get cumulative change of:  -0.06892222608704324
# vs adding way
# We get cumulative change of:  -0.06051971850337923
# Using these changes: [-0.11499746 -0.03321509  0.08060319  0.01163335 -0.02137647]
# We get cumulative change of:  -0.08466637610823569
# vs adding way
# We get cumulative change of:  -0.0773524833592919
# Using these changes: [-0.03321509  0.08060319  0.01163335 -0.02137647  0.04455407]
# We get cumulative change of:  0.08035335520567055
# vs adding way
# We get cumulative change of:  0.08219904821975277
# Using these changes: [ 0.08060319  0.01163335 -0.02137647  0.04455407  0.01809675]
# We get cumulative change of:  0.13769280589180877
# vs adding way
# We get cumulative change of:  0.1335108856549393
# Using these changes: [ 0.01163335 -0.02137647  0.04455407  0.01809675 -0.02671621]
# We get cumulative change of:  0.024703591701880745
# vs adding way
# We get cumulative change of:  0.02619148939565441
# Using these changes: [-0.02137647  0.04455407  0.01809675 -0.02671621  0.02463782]
# We get cumulative change of:  0.03787608490189043
# vs adding way
# We get cumulative change of:  0.03919596551304172
# Using these changes: [ 0.04455407  0.01809675 -0.02671621  0.02463782  0.01666958]
# We get cumulative change of:  0.07822570137122065
# vs adding way
# We get cumulative change of:  0.0772420142076573
# Using these changes: [ 0.01809675 -0.02671621  0.02463782  0.01666958 -0.04412055]
# We get cumulative change of:  -0.013307384057014482
# vs adding way
# We get cumulative change of:  -0.01143260844036853
# Using these changes: [-0.02671621  0.02463782  0.01666958 -0.04412055 -0.00028267]
# We get cumulative change of:  -0.031119870159522223
# vs adding way
# We get cumulative change of:  -0.029812024574129126
# Using these changes: [ 0.02463782  0.01666958 -0.04412055 -0.00028267  0.00538017]
# We get cumulative change of:  0.0008312870621836055
# vs adding way
# We get cumulative change of:  0.002284354009414624
# Using these changes: [ 0.01666958 -0.04412055 -0.00028267  0.00538017 -0.00102659]
# We get cumulative change of:  -0.024236833643628275
# vs adding way
# We get cumulative change of:  -0.023380056130841043
# Using these changes: [-0.04412055 -0.00028267  0.00538017 -0.00102659 -0.00169209]
# We get cumulative change of:  -0.04185970690356999
# vs adding way
# We get cumulative change of:  -0.041741723934709096
# Using these changes: [-0.00028267  0.00538017 -0.00102659 -0.00169209  0.00368292]
# We get cumulative change of:  0.006056827009378152
# vs adding way
# We get cumulative change of:  0.006061745379322914
# Using these changes: [ 0.00538017 -0.00102659 -0.00169209  0.00368292 -0.03152867]
# We get cumulative change of:  -0.025387314545265216
# vs adding way
# We get cumulative change of:  -0.025184256308790398
# Using these changes: [-0.00102659 -0.00169209  0.00368292 -0.03152867  0.01621665]
# We get cumulative change of:  -0.014882462199218516
# vs adding way
# We get cumulative change of:  -0.014347776958661629
# Using these changes: [-0.00169209  0.00368292 -0.03152867  0.01621665  0.0011802 ]
# We get cumulative change of:  -0.012706287359953827
# vs adding way
# We get cumulative change of:  -0.012140993784844345
# Using these changes: [ 0.00368292 -0.03152867  0.01621665  0.0011802   0.00704059]
# We get cumulative change of:  -0.004069957339259411
# vs adding way
# We get cumulative change of:  -0.003408317315660825
# Using these changes: [-0.03152867  0.01621665  0.0011802   0.00704059 -0.03691096]
# We get cumulative change of:  -0.044350272622113884
# vs adding way
# We get cumulative change of:  -0.044002197122951614
# Using these changes: [ 0.01621665  0.0011802   0.00704059 -0.03691096  0.00217986]
# We get cumulative change of:  -0.011088006439495812
# vs adding way
# We get cumulative change of:  -0.010293663263747699
# Using these changes: [ 0.0011802   0.00704059 -0.03691096  0.00217986 -0.00037582]
# We get cumulative change of:  -0.027234655669515995
# vs adding way
# We get cumulative change of:  -0.026886134474462087
# Using these changes: [ 0.00704059 -0.03691096  0.00217986 -0.00037582  0.00086739]
# We get cumulative change of:  -0.027538587502503487
# vs adding way
# We get cumulative change of:  -0.027198944273837955
# Using these changes: [-3.69109601e-02  2.17986459e-03 -3.75821593e-04  8.67386460e-04
#  -3.49577641e-05]
# We get cumulative change of:  -0.03437117575915527
# vs adding way
# We get cumulative change of:  -0.03427448845098535
# Using these changes: [ 2.17986459e-03 -3.75821593e-04  8.67386460e-04 -3.49577641e-05
#   5.35047284e-02]
# We get cumulative change of:  0.05628295009827644
# vs adding way
# We get cumulative change of:  0.05614120010313284
# Using these changes: [-3.75821593e-04  8.67386460e-04 -3.49577641e-05  5.35047284e-02
#   4.86088165e-04]
# We get cumulative change of:  0.054497734471976145
# vs adding way
# We get cumulative change of:  0.05444742368228328
# Using these changes: [ 8.67386460e-04 -3.49577641e-05  5.35047284e-02  4.86088165e-04
#   2.39760021e-03]
# We get cumulative change of:  0.057423401007359764
# vs adding way
# We get cumulative change of:  0.05722084548407602
# Using these changes: [-3.49577641e-05  5.35047284e-02  4.86088165e-04  2.39760021e-03
#   2.69005905e-03]
# We get cumulative change of:  0.0593490673639292
# vs adding way
# We get cumulative change of:  0.059043518078287005
# Using these changes: [ 0.05350473  0.00048609  0.0023976   0.00269006 -0.00623537]
# We get cumulative change of:  0.05278044178200547
# vs adding way
# We get cumulative change of:  0.052843110526312964
# Using these changes: [ 0.00048609  0.0023976   0.00269006 -0.00623537 -0.02223074]
# We get cumulative change of:  -0.02290295793798902
# vs adding way
# We get cumulative change of:  -0.022892357481201886
# Using these changes: [ 0.0023976   0.00269006 -0.00623537 -0.02223074 -0.02177302]
# We get cumulative change of:  -0.044641697720053664
# vs adding way
# We get cumulative change of:  -0.04515146357806532
# Using these changes: [ 0.00269006 -0.00623537 -0.02223074 -0.02177302  0.04173852]
# We get cumulative change of:  -0.007146920098458076
# vs adding way
# We get cumulative change of:  -0.005810542984658329
# Using these changes: [-0.00623537 -0.02223074 -0.02177302  0.04173852 -0.00725997]
# We get cumulative change of:  -0.01699933281441135
# vs adding way
# We get cumulative change of:  -0.015760571330206363
# Using these changes: [-0.02223074 -0.02177302  0.04173852 -0.00725997  0.00119295]
# We get cumulative change of:  -0.009651473289876145
# vs adding way
# We get cumulative change of:  -0.008332251920195488
# Using these changes: [-0.02177302  0.04173852 -0.00725997  0.00119295 -0.03864185]
# We get cumulative change of:  -0.02627371696939429
# vs adding way
# We get cumulative change of:  -0.024743362221759768
# Using these changes: [ 0.04173852 -0.00725997  0.00119295 -0.03864185  0.02222555]
# We get cumulative change of:  0.01752241470293403
# vs adding way
# We get cumulative change of:  0.019255201295215407
# Using these changes: [-0.00725997  0.00119295 -0.03864185  0.02222555 -0.05847564]
# We get cumulative change of:  -0.08036218146681506
# vs adding way
# We get cumulative change of:  -0.08095895905127626
# Using these changes: [ 0.00119295 -0.03864185  0.02222555 -0.05847564  0.1231146 ]
# We get cumulative change of:  0.040412019304961966
# vs adding way
# We get cumulative change of:  0.04941560946550938
# Using these changes: [-0.03864185  0.02222555 -0.05847564  0.1231146   0.00233078]
# We get cumulative change of:  0.041594416388791355
# vs adding way
# We get cumulative change of:  0.0505534352569319
# Using these changes: [ 0.02222555 -0.05847564  0.1231146   0.00233078  0.00487576]
# We get cumulative change of:  0.0887440701316422
# vs adding way
# We get cumulative change of:  0.09407104939459376
# Using these changes: [-0.05847564  0.1231146   0.00233078  0.00487576  0.01024288]
# We get cumulative change of:  0.07598166859234357
# vs adding way
# We get cumulative change of:  0.08208838677039654
# Using these changes: [0.1231146  0.00233078 0.00487576 0.01024288 0.03396813]
# We get cumulative change of:  0.18162715633799853
# vs adding way
# We get cumulative change of:  0.17453215527333188
# Using these changes: [ 0.00233078  0.00487576  0.01024288  0.03396813 -0.01588225]
# We get cumulative change of:  0.03538878304113657
# vs adding way
# We get cumulative change of:  0.03553530577159403
# Using these changes: [ 0.00487576  0.01024288  0.03396813 -0.01588225  0.09264033]
# We get cumulative change of:  0.1286768450021447
# vs adding way
# We get cumulative change of:  0.12584485657117284
# Using these changes: [ 0.01024288  0.03396813 -0.01588225  0.09264033  0.06813614]
# We get cumulative change of:  0.19973092713841267
# vs adding way
# We get cumulative change of:  0.18910523566502746
# Using these changes: [ 0.03396813 -0.01588225  0.09264033  0.06813614 -0.01040118]
# We get cumulative change of:  0.1752147198941001
# vs adding way
# We get cumulative change of:  0.1684611701287405
# Using these changes: [-0.01588225  0.09264033  0.06813614 -0.01040118  0.08273819]
# We get cumulative change of:  0.23064707962983233
# vs adding way
# We get cumulative change of:  0.21723123087549412
# Using these changes: [ 0.09264033  0.06813614 -0.01040118  0.08273819  0.00134971]
# We get cumulative change of:  0.2521957773686483
# vs adding way
# We get cumulative change of:  0.23446318655085907
# Using these changes: [ 0.06813614 -0.01040118  0.08273819  0.00134971  0.00335037]
# We get cumulative change of:  0.14986703597612605
# vs adding way
# We get cumulative change of:  0.14517322738117677
# Using these changes: [-0.01040118  0.08273819  0.00134971  0.00335037 -0.01903897]
# We get cumulative change of:  0.05602151732204752
# vs adding way
# We get cumulative change of:  0.0579981130171473
# Using these changes: [ 0.08273819  0.00134971  0.00335037 -0.01903897 -0.04316855]
# We get cumulative change of:  0.021054777252549783
# vs adding way
# We get cumulative change of:  0.02523074601338493
# Using these changes: [ 0.00134971  0.00335037 -0.01903897 -0.04316855  0.06370189]
# We get cumulative change of:  0.003102970673415806
# vs adding way
# We get cumulative change of:  0.006194444543122124
# Using these changes: [ 0.00335037 -0.01903897 -0.04316855  0.06370189  0.00787541]
# We get cumulative change of:  0.00964010466950982
# vs adding way
# We get cumulative change of:  0.012720152663344475
# Using these changes: [-0.01903897 -0.04316855  0.06370189  0.00787541 -0.00164067]
# We get cumulative change of:  0.004617778956330643
# vs adding way
# We get cumulative change of:  0.007729114424190775
# Using these changes: [-0.04316855  0.06370189  0.00787541 -0.00164067  0.01254447]
# We get cumulative change of:  0.0369628871643064
# vs adding way
# We get cumulative change of:  0.03931255968524017
# Using these changes: [ 0.06370189  0.00787541 -0.00164067  0.01254447 -0.00740212]
# We get cumulative change of:  0.07572463437356936
# vs adding way
# We get cumulative change of:  0.07507898803302737
# Using these changes: [ 0.00787541 -0.00164067  0.01254447 -0.00740212 -0.00781568]
# We get cumulative change of:  0.003398719243100201
# vs adding way
# We get cumulative change of:  0.0035614174259263054
# Using these changes: [-0.00164067  0.01254447 -0.00740212 -0.00781568  0.01769712]
# We get cumulative change of:  0.013176798365682307
# vs adding way
# We get cumulative change of:  0.013383121749537819
# Using these changes: [ 0.01254447 -0.00740212 -0.00781568  0.01769712 -0.00110924]
# We get cumulative change of:  0.013716113822616505
# vs adding way
# We get cumulative change of:  0.0139145498486406
# Using these changes: [-0.00740212 -0.00781568  0.01769712 -0.00110924 -0.00380502]
# We get cumulative change of:  -0.0026522968506497158
# vs adding way
# We get cumulative change of:  -0.002434942433487741
# Using these changes: [-0.00781568  0.01769712 -0.00110924 -0.00380502 -0.01504039]
# We get cumulative change of:  -0.0103271136012274
# vs adding way
# We get cumulative change of:  -0.010073208208306372
# Using these changes: [ 0.01769712 -0.00110924 -0.00380502 -0.01504039  0.00252259]
# We get cumulative change of:  -1.5005568941628411e-05
# vs adding way
# We get cumulative change of:  0.00026506821810945436
# Using these changes: [-0.00110924 -0.00380502 -0.01504039  0.00252259  0.03047677]
# We get cumulative change of:  0.012542225859886846
# vs adding way
# We get cumulative change of:  0.013044718217233187
# Using these changes: [-0.00380502 -0.01504039  0.00252259  0.03047677  0.02700703]
# We get cumulative change of:  0.04104275281523795
# vs adding way
# We get cumulative change of:  0.04116099064809131
# Using these changes: [-0.01504039  0.00252259  0.03047677  0.02700703 -0.01002105]
# We get cumulative change of:  0.03454688213318202
# vs adding way
# We get cumulative change of:  0.03494495988530644
# Using these changes: [ 0.00252259  0.03047677  0.02700703 -0.01002105 -0.0026186 ]
# We get cumulative change of:  0.0475940393457579
# vs adding way
# We get cumulative change of:  0.04736674872900526
# Using these changes: [ 0.03047677  0.02700703 -0.01002105 -0.0026186   0.03285087]
# We get cumulative change of:  0.07928581423502146
# vs adding way
# We get cumulative change of:  0.0776950239757932
# Using these changes: [ 0.02700703 -0.01002105 -0.0026186   0.03285087 -0.00473141]
# We get cumulative change of:  0.04240998049785305
# vs adding way
# We get cumulative change of:  0.04248684328837282
# Using these changes: [-0.01002105 -0.0026186   0.03285087 -0.00473141 -0.00549709]
# We get cumulative change of:  0.009418367976315123
# vs adding way
# We get cumulative change of:  0.009982724227617035
# Using these changes: [-0.0026186   0.03285087 -0.00473141 -0.00549709 -0.22284166]
# We get cumulative change of:  -0.20758123053918787
# vs adding way
# We get cumulative change of:  -0.2028378878814725
# Using these changes: [ 0.03285087 -0.00473141 -0.00549709 -0.22284166  0.14015801]
# We get cumulative change of:  -0.09414532252049457
# vs adding way
# We get cumulative change of:  -0.060061278696211695
# Using these changes: [-0.00473141 -0.00549709 -0.22284166  0.14015801 -0.12058897]
# We get cumulative change of:  -0.22871867005734714
# vs adding way
# We get cumulative change of:  -0.21350112113865727
# Using these changes: [-0.00549709 -0.22284166  0.14015801 -0.12058897 -0.13530006]
# We get cumulative change of:  -0.32990257640292653
# vs adding way
# We get cumulative change of:  -0.34406977307119146
# Using these changes: [-2.22841661e-01  1.40158011e-01 -1.20588973e-01 -1.35300065e-01
#   1.53017228e-04]
# We get cumulative change of:  -0.3260955296257052
# vs adding way
# We get cumulative change of:  -0.33841967058878786
# Using these changes: [ 0.14015801 -0.12058897 -0.13530006  0.00015302 -0.00064376]
# We get cumulative change of:  -0.13341901858277017
# vs adding way
# We get cumulative change of:  -0.1162217717994678
# Using these changes: [-0.12058897 -0.13530006  0.00015302 -0.00064376  0.05092   ]
# We get cumulative change of:  -0.20124467004512836
# vs adding way
# We get cumulative change of:  -0.20545977900932044
# Using these changes: [-0.13530006  0.00015302 -0.00064376  0.05092     0.07742814]
# We get cumulative change of:  -0.021388808345804033
# vs adding way
# We get cumulative change of:  -0.0074426615116490735
# Using these changes: [ 0.00015302 -0.00064376  0.05092     0.07742814 -0.06865355]
# We get cumulative change of:  0.0540373876957263
# vs adding way
# We get cumulative change of:  0.05920385488564328
# Using these changes: [-0.00064376  0.05092     0.07742814 -0.06865355 -0.02303001]
# We get cumulative change of:  0.029605345779053716
# vs adding way
# We get cumulative change of:  0.036020824828794096
# Using these changes: [ 0.05092     0.07742814 -0.06865355 -0.02303001 -0.02504943]
# We get cumulative change of:  0.004460953206502971
# vs adding way
# We get cumulative change of:  0.01161515748466646
# Using these changes: [ 0.07742814 -0.06865355 -0.02303001 -0.02504943  0.05958227]
# We get cumulative change of:  0.012740277533966893
# vs adding way
# We get cumulative change of:  0.020277423076981882
# Using these changes: [-0.06865355 -0.02303001 -0.02504943  0.05958227  0.00123187]
# We get cumulative change of:  -0.05888123950266333
# vs adding way
# We get cumulative change of:  -0.05591885341028269
# Using these changes: [-0.02303001 -0.02504943  0.05958227  0.00123187 -0.00052612]
# We get cumulative change of:  0.009961027912179343
# vs adding way
# We get cumulative change of:  0.012208575527973498
# Using these changes: [-0.02504943  0.05958227  0.00123187 -0.00052612 -0.00267076]
# We get cumulative change of:  0.031007790386838652
# vs adding way
# We get cumulative change of:  0.0325678316740865
# Using these changes: [ 0.05958227  0.00123187 -0.00052612 -0.00267076 -0.01493644]
# We get cumulative change of:  0.04170225207070244
# vs adding way
# We get cumulative change of:  0.042680821718742434
# Using these changes: [ 0.00123187 -0.00052612 -0.00267076 -0.01493644  0.00536537]
# We get cumulative change of:  -0.011599762484273635
# vs adding way
# We get cumulative change of:  -0.011536080888268296
# Using these changes: [-5.26119442e-04 -2.67075668e-03 -1.49364394e-02  5.36536680e-03
#   9.93332479e-05]
# We get cumulative change of:  -0.012717782719716686
# vs adding way
# We get cumulative change of:  -0.012668615509528358
# Using these changes: [-2.67075668e-03 -1.49364394e-02  5.36536680e-03  9.93332479e-05
#   3.86201425e-03]
# We get cumulative change of:  -0.00838317583871906
# vs adding way
# We get cumulative change of:  -0.008280481818660479
# Using these changes: [-1.49364394e-02  5.36536680e-03  9.93332479e-05  3.86201425e-03
#   2.26560695e-02]
# We get cumulative change of:  0.016798585448419168
# vs adding way
# We get cumulative change of:  0.017046344348424003
# Using these changes: [5.36536680e-03 9.93332479e-05 3.86201425e-03 2.26560695e-02
#  7.12745022e-02]
# We get cumulative change of:  0.10578691780592475
# vs adding way
# We get cumulative change of:  0.10325728599978179
# Using these changes: [ 9.93332479e-05  3.86201425e-03  2.26560695e-02  7.12745022e-02
#  -1.96307667e-03]
# We get cumulative change of:  0.09772646815680419
# vs adding way
# We get cumulative change of:  0.09592884252884237
# Using these changes: [ 0.00386201  0.02265607  0.0712745  -0.00196308 -0.00265609]
# We get cumulative change of:  0.0947020690091327
# vs adding way
# We get cumulative change of:  0.09317342061017375
# Using these changes: [ 0.02265607  0.0712745  -0.00196308 -0.00265609 -0.00816054]
# We get cumulative change of:  0.08159159176950803
# vs adding way
# We get cumulative change of:  0.08115087085703354
# Using these changes: [ 0.0712745  -0.00196308 -0.00265609 -0.00816054 -0.0203646 ]
# We get cumulative change of:  0.03609164457702274
# vs adding way
# We get cumulative change of:  0.038130198810690685
# Using these changes: [-0.00196308 -0.00265609 -0.00816054 -0.0203646   0.0519486 ]
# We get cumulative change of:  0.017400448443144034
# vs adding way
# We get cumulative change of:  0.018804300431867316
# Using these changes: [-0.00265609 -0.00816054 -0.0203646   0.0519486  -0.00311848]
# We get cumulative change of:  0.01622263208624819
# vs adding way
# We get cumulative change of:  0.017648900692384784
# Using these changes: [-0.00816054 -0.0203646   0.0519486  -0.00311848 -0.00807745]
# We get cumulative change of:  0.010698648398290489
# vs adding way
# We get cumulative change of:  0.012227537967804958
# Using these changes: [-0.0203646   0.0519486  -0.00311848 -0.00807745  0.03590983]
# We get cumulative change of:  0.05560698500828409
# vs adding way
# We get cumulative change of:  0.05629790513928479
# Using these changes: [ 0.0519486  -0.00311848 -0.00807745  0.03590983 -0.0123934 ]
# We get cumulative change of:  0.06419636376920557
# vs adding way
# We get cumulative change of:  0.06426910994912416
# Using these changes: [-0.00311848 -0.00807745  0.03590983 -0.0123934   0.04250774]
# We get cumulative change of:  0.05464558282136833
# vs adding way
# We get cumulative change of:  0.05482824825692756
# Using these changes: [-0.00807745  0.03590983 -0.0123934   0.04250774  0.03603336]
# We get cumulative change of:  0.09606606708817766
# vs adding way
# We get cumulative change of:  0.09398008858718421
# Using these changes: [ 0.03590983 -0.0123934   0.04250774  0.03603336 -0.00304029]
# We get cumulative change of:  0.1016320858930333
# vs adding way
# We get cumulative change of:  0.0990172480470708
# Using these changes: [-0.0123934   0.04250774  0.03603336 -0.00304029 -0.00303566]
# We get cumulative change of:  0.06021574025513998
# vs adding way
# We get cumulative change of:  0.06007175963273881
# Using these changes: [ 0.04250774  0.03603336 -0.00304029 -0.00303566  0.02122742]
# We get cumulative change of:  0.09630837525356206
# vs adding way
# We get cumulative change of:  0.09369258156882254
# Using these changes: [ 0.03603336 -0.00304029 -0.00303566  0.02122742 -0.00674994]
# We get cumulative change of:  0.04450865988666508
# vs adding way
# We get cumulative change of:  0.04443490413961648
# Using these changes: [-0.00304029 -0.00303566  0.02122742 -0.00674994  0.03698943]
# We get cumulative change of:  0.045472544942776416
# vs adding way
# We get cumulative change of:  0.0453909680914667
# Using these changes: [-0.00303566  0.02122742 -0.00674994  0.03698943 -0.00870726]
# We get cumulative change of:  0.039529818433130304
# vs adding way
# We get cumulative change of:  0.03972400063754067
# Using these changes: [ 0.02122742 -0.00674994  0.03698943 -0.00870726 -0.00858839]
# We get cumulative change of:  0.033740007940380234
# vs adding way
# We get cumulative change of:  0.034171264666809864
# Using these changes: [-0.00674994  0.03698943 -0.00870726 -0.00858839 -0.00181512]
# We get cumulative change of:  0.010415139830928677
# vs adding way
# We get cumulative change of:  0.011128725154097907
# Using these changes: [ 0.03698943 -0.00870726 -0.00858839 -0.00181512 -0.00394064]
# We get cumulative change of:  0.013272985496896705
# vs adding way
# We get cumulative change of:  0.013938021334241157
# Using these changes: [-0.00870726 -0.00858839 -0.00181512 -0.00394064 -0.00476443]
# We get cumulative change of:  -0.027525939685422718
# vs adding way
# We get cumulative change of:  -0.027815834426321517
# Using these changes: [-0.00858839 -0.00181512 -0.00394064 -0.00476443  0.02922934]
# We get cumulative change of:  0.009690467689105198
# vs adding way
# We get cumulative change of:  0.010120760458319444
# Using these changes: [-0.00181512 -0.00394064 -0.00476443  0.02922934  0.00010925]
# We get cumulative change of:  0.01854847116265268
# vs adding way
# We get cumulative change of:  0.018818403688641627
# Using these changes: [-0.00394064 -0.00476443  0.02922934  0.00010925  0.00071222]
# We get cumulative change of:  0.021127365721460123
# vs adding way
# We get cumulative change of:  0.021345739049346668
# Using these changes: [-0.00476443  0.02922934  0.00010925  0.00071222  0.0705213 ]
# We get cumulative change of:  0.09746330525418867
# vs adding way
# We get cumulative change of:  0.09580768150355878
# Using these changes: [ 0.02922934  0.00010925  0.00071222  0.0705213  -0.00017588]
# We get cumulative change of:  0.10252317579022052
# vs adding way
# We get cumulative change of:  0.10039622958859906
# Using these changes: [ 0.00010925  0.00071222  0.0705213  -0.00017588 -0.00086502]
# We get cumulative change of:  0.07028573580374853
# vs adding way
# We get cumulative change of:  0.07030187904439122
# Using these changes: [ 0.00071222  0.0705213  -0.00017588 -0.00086502 -0.02656959]
# We get cumulative change of:  0.041734869759724624
# vs adding way
# We get cumulative change of:  0.043623035922824904
# Using these changes: [ 0.0705213  -0.00017588 -0.00086502 -0.02656959 -0.03255487]
# We get cumulative change of:  0.007104047536522051
# vs adding way
# We get cumulative change of:  0.010355946575519415
# Using these changes: [-0.00017588 -0.00086502 -0.02656959 -0.03255487  0.07880251]
# We get cumulative change of:  0.014894676417678498
# vs adding way
# We get cumulative change of:  0.01863715069163363
# Using these changes: [-0.00086502 -0.02656959 -0.03255487  0.07880251 -0.01359175]
# We get cumulative change of:  0.001276582540294724
# vs adding way
# We get cumulative change of:  0.005221277058581331
# Using these changes: [-0.02656959 -0.03255487  0.07880251 -0.01359175 -0.00092365]
# We get cumulative change of:  0.0012178176377812822
# vs adding way
# We get cumulative change of:  0.005162637846387486
# Using these changes: [-0.03255487  0.07880251 -0.01359175 -0.00092365 -0.00929266]
# We get cumulative change of:  0.018987935793414623
# vs adding way
# We get cumulative change of:  0.022439571048023188
# Using these changes: [ 0.07880251 -0.01359175 -0.00092365 -0.00929266  0.00011116]
# We get cumulative change of:  0.053394316108520856
# vs adding way
# We get cumulative change of:  0.05510559576832885
# Using these changes: [-0.01359175 -0.00092365 -0.00929266  0.00011116  0.02081316]
# We get cumulative change of:  -0.0032292537123267406
# vs adding way
# We get cumulative change of:  -0.002883751782350341
# Using these changes: [-0.00092365 -0.00929266  0.00011116  0.02081316 -0.01657125]
# We get cumulative change of:  -0.006240048105728424
# vs adding way
# We get cumulative change of:  -0.005863245742633971
# Using these changes: [-0.00929266  0.00011116  0.02081316 -0.01657125 -0.00332622]
# We get cumulative change of:  -0.008629827673871993
# vs adding way
# We get cumulative change of:  -0.008265810097849657
# Using these changes: [ 0.00011116  0.02081316 -0.01657125 -0.00332622  0.00167366]
# We get cumulative change of:  0.0023438244670055397
# vs adding way
# We get cumulative change of:  0.002700505041088319
# Using these changes: [ 0.02081316 -0.01657125 -0.00332622  0.00167366  0.00516541]
# We get cumulative change of:  0.007409366418204
# vs adding way
# We get cumulative change of:  0.007754763759405647
# Using these changes: [-0.01657125 -0.00332622  0.00167366  0.00516541  0.00896397]
# We get cumulative change of:  -0.004284233963253836
# vs adding way
# We get cumulative change of:  -0.004094422434575029
# Using these changes: [-0.00332622  0.00167366  0.00516541  0.00896397 -0.00791006]
# We get cumulative change of:  0.0044851648628845275
# vs adding way
# We get cumulative change of:  0.004566763059127732
# Using these changes: [ 0.00167366  0.00516541  0.00896397 -0.00791006 -0.00202335]
# We get cumulative change of:  0.005798243051688523
# vs adding way
# We get cumulative change of:  0.005869630089390232
# Using these changes: [ 0.00516541  0.00896397 -0.00791006 -0.00202335  0.00524017]
# We get cumulative change of:  0.00937944255468226
# vs adding way
# We get cumulative change of:  0.00943614377426416
# Using these changes: [ 0.00896397 -0.00791006 -0.00202335  0.00524017 -0.00727215]
# We get cumulative change of:  -0.003110269394415499
# vs adding way
# We get cumulative change of:  -0.0030014252451889822
# Using these changes: [-0.00791006 -0.00202335  0.00524017 -0.00727215 -0.00579814]
# We get cumulative change of:  -0.017695724744147934
# vs adding way
# We get cumulative change of:  -0.017763538382159494
# Using these changes: [-0.00202335  0.00524017 -0.00727215 -0.00579814 -0.02225399]
# We get cumulative change of:  -0.03189816416973601
# vs adding way
# We get cumulative change of:  -0.03210746175239343
# Using these changes: [ 0.00524017 -0.00727215 -0.00579814 -0.02225399  0.02194644]
# We get cumulative change of:  -0.00864592058579583
# vs adding way
# We get cumulative change of:  -0.008137673388029398
# Using these changes: [-0.00727215 -0.00579814 -0.02225399  0.02194644 -0.04284633]
# We get cumulative change of:  -0.056068162764114415
# vs adding way
# We get cumulative change of:  -0.05622416816453246
# Using these changes: [-0.00579814 -0.02225399  0.02194644 -0.04284633  0.0014764 ]
# We get cumulative change of:  -0.04774963129437393
# vs adding way
# We get cumulative change of:  -0.04747561504382947
# Using these changes: [-0.02225399  0.02194644 -0.04284633  0.0014764   0.01057877]
# We get cumulative change of:  -0.03206375973332265
# vs adding way
# We get cumulative change of:  -0.031098700732763218
# Using these changes: [ 0.02194644 -0.04284633  0.0014764   0.01057877 -0.00298395]
# We get cumulative change of:  -0.012987064440382667
# vs adding way
# We get cumulative change of:  -0.011828668244214913
# Using these changes: [-0.04284633  0.0014764   0.01057877 -0.00298395 -0.00405373]
# We get cumulative change of:  -0.03809845589641214
# vs adding way
# We get cumulative change of:  -0.03782883105513368
# Using these changes: [ 0.0014764   0.01057877 -0.00298395 -0.00405373 -0.00252583]
# We get cumulative change of:  0.002422045080928026
# vs adding way
# We get cumulative change of:  0.0024916639544002583
# Using these changes: [ 1.05787749e-02 -2.98395279e-03 -4.05372603e-03 -2.52583035e-03
#   3.28583335e-05]
# We get cumulative change of:  0.0009771421237003697
# vs adding way
# We get cumulative change of:  0.0010481240637035816
# Using these changes: [-2.98395279e-03 -4.05372603e-03 -2.52583035e-03  3.28583335e-05
#  -8.85826989e-03]
# We get cumulative change of:  -0.018275228925517584
# vs adding way
# We get cumulative change of:  -0.018388920729928482
# Using these changes: [-4.05372603e-03 -2.52583035e-03  3.28583335e-05 -8.85826989e-03
#  -2.12643497e-02]
# We get cumulative change of:  -0.0362752586310382
# vs adding way
# We get cumulative change of:  -0.036669317634928755
# Using these changes: [-2.52583035e-03  3.28583335e-05 -8.85826989e-03 -2.12643497e-02
#   9.75552330e-03]
# We get cumulative change of:  -0.022912775545734454
# vs adding way
# We get cumulative change of:  -0.02286006830419629
# Using these changes: [ 3.28583335e-05 -8.85826989e-03 -2.12643497e-02  9.75552330e-03
#   7.15505114e-03]
# We get cumulative change of:  -0.013429757421637545
# vs adding way
# We get cumulative change of:  -0.013179186810343246
# Using these changes: [-0.00885827 -0.02126435  0.00975552  0.00715505 -0.00166057]
# We get cumulative change of:  -0.015100385771604663
# vs adding way
# We get cumulative change of:  -0.01487261234856374
# Using these changes: [-0.02126435  0.00975552  0.00715505 -0.00166057 -0.02207091]
# We get cumulative change of:  -0.028229810439845737
# vs adding way
# We get cumulative change of:  -0.02808524893913744
# Using these changes: [ 0.00975552  0.00715505 -0.00166057 -0.02207091  0.00460712]
# We get cumulative change of:  -0.0025424589944792464
# vs adding way
# We get cumulative change of:  -0.002213775527356132
# Using these changes: [ 0.00715505 -0.00166057 -0.02207091  0.00460712 -0.01212023]
# We get cumulative change of:  -0.02415178041571875
# vs adding way
# We get cumulative change of:  -0.024089525384160204
# Using these changes: [-0.00166057 -0.02207091  0.00460712 -0.01212023  0.0020138 ]
# We get cumulative change of:  -0.029133221629426997
# vs adding way
# We get cumulative change of:  -0.029230779505107884
# Using these changes: [-0.02207091  0.00460712 -0.01212023  0.0020138  -0.0187046 ]
# We get cumulative change of:  -0.04570823274070457
# vs adding way
# We get cumulative change of:  -0.046274814340844794
# Using these changes: [ 0.00460712 -0.01212023  0.0020138  -0.0187046   0.00997003]
# We get cumulative change of:  -0.014441754200724799
# vs adding way
# We get cumulative change of:  -0.014233880880963223
# Using these changes: [-0.01212023  0.0020138  -0.0187046   0.00997003 -0.0768847 ]
# We get cumulative change of:  -0.09438836992746102
# vs adding way
# We get cumulative change of:  -0.09572570545721781
# Using these changes: [ 0.0020138  -0.0187046   0.00997003 -0.0768847  -0.06316037]
# We get cumulative change of:  -0.14117801782238293
# vs adding way
# We get cumulative change of:  -0.14676584808229542
# Using these changes: [-0.0187046   0.00997003 -0.0768847  -0.06316037 -0.02235674]
# We get cumulative change of:  -0.1620659049887404
# vs adding way
# We get cumulative change of:  -0.17113638303094258
# Using these changes: [ 0.00997003 -0.0768847  -0.06316037 -0.02235674  0.00670713]
# We get cumulative change of:  -0.14036666968670708
# vs adding way
# We get cumulative change of:  -0.14572464734922452
# Using these changes: [-0.0768847  -0.06316037 -0.02235674  0.00670713  0.00902766]
# We get cumulative change of:  -0.14116876361413644
# vs adding way
# We get cumulative change of:  -0.14666701521347247
# Using these changes: [-0.06316037 -0.02235674  0.00670713  0.00902766  0.00520354]
# We get cumulative change of:  -0.06479700248679165
# vs adding way
# We get cumulative change of:  -0.06457877932692735
# Using these changes: [-0.02235674  0.00670713  0.00902766  0.00520354 -0.05855251]
# We get cumulative change of:  -0.06019719656006439
# vs adding way
# We get cumulative change of:  -0.0599709236018281
# Using these changes: [ 0.00670713  0.00902766  0.00520354 -0.05855251  0.04160119]
# We get cumulative change of:  0.0012851935726647667
# vs adding way
# We get cumulative change of:  0.003987009093635474
# Using these changes: [ 0.00902766  0.00520354 -0.05855251  0.04160119 -0.0005229 ]
# We get cumulative change of:  -0.005905904649720184
# vs adding way
# We get cumulative change of:  -0.003243028787339397
# Using these changes: [ 0.00520354 -0.05855251  0.04160119 -0.0005229  -0.06700159]
# We get cumulative change of:  -0.08080992836653167
# vs adding way
# We get cumulative change of:  -0.0792722820165842
# Using these changes: [-0.05855251  0.04160119 -0.0005229  -0.06700159 -0.00029553]
# We get cumulative change of:  -0.08583845061132889
# vs adding way
# We get cumulative change of:  -0.08477134961145538
# Using these changes: [ 0.04160119 -0.0005229  -0.06700159 -0.00029553 -0.00463477]
# We get cumulative change of:  -0.03348340404726524
# vs adding way
# We get cumulative change of:  -0.03085360714192087
# Using these changes: [-0.0005229  -0.06700159 -0.00029553 -0.00463477 -0.00527662]
# We get cumulative change of:  -0.07698199632733782
# vs adding way
# We get cumulative change of:  -0.07773142163512892
# Using these changes: [-0.06700159 -0.00029553 -0.00463477 -0.00527662 -0.0008583 ]
# We get cumulative change of:  -0.07729173854587523
# vs adding way
# We get cumulative change of:  -0.07806682165093182
# Using these changes: [-0.00029553 -0.00463477 -0.00527662 -0.0008583   0.07357155]
# We get cumulative change of:  0.061731004936868894
# vs adding way
# We get cumulative change of:  0.06250631881982749
# Using these changes: [-0.00463477 -0.00527662 -0.0008583   0.07357155 -0.036597  ]
# We get cumulative change of:  0.023177213106963634
# vs adding way
# We get cumulative change of:  0.02620484721383498
# Using these changes: [-0.00527662 -0.0008583   0.07357155 -0.036597   -0.0363232 ]
# We get cumulative change of:  -0.009396640229042075
# vs adding way
# We get cumulative change of:  -0.005483584242826134
# Using these changes: [-0.0008583   0.07357155 -0.036597   -0.0363232   0.14394844]
# We get cumulative change of:  0.13921035186260533
# vs adding way
# We get cumulative change of:  0.14374147950029725
# Using these changes: [ 0.07357155 -0.036597   -0.0363232   0.14394844 -0.0112728 ]
# We get cumulative change of:  0.12733586324214508
# vs adding way
# We get cumulative change of:  0.1333269878509309
# Using these changes: [-0.036597   -0.0363232   0.14394844 -0.0112728  -0.01865972]
# We get cumulative change of:  0.030485670018042477
# vs adding way
# We get cumulative change of:  0.0410957237755909
# Using these changes: [-0.0363232   0.14394844 -0.0112728  -0.01865972 -0.01496103]
# We get cumulative change of:  0.053628177847574454
# vs adding way
# We get cumulative change of:  0.06273169797946176
# Using these changes: [ 0.14394844 -0.0112728  -0.01865972 -0.01496103  0.05550799]
# We get cumulative change of:  0.15403105945898754
# vs adding way
# We get cumulative change of:  0.15456288610709346
# Using these changes: [-0.0112728  -0.01865972 -0.01496103  0.05550799 -0.00431665]
# We get cumulative change of:  0.004459173025765262
# vs adding way
# We get cumulative change of:  0.006297789295554024
# Using these changes: [-0.01865972 -0.01496103  0.05550799 -0.00431665 -0.02328692]
# We get cumulative change of:  -0.007746116516681334
# vs adding way
# We get cumulative change of:  -0.005716339430178463
# Using these changes: [-0.01496103  0.05550799 -0.00431665 -0.02328692 -0.00870421]
# We get cumulative change of:  0.002320107517903347
# vs adding way
# We get cumulative change of:  0.004239168227702317
# Using these changes: [ 0.05550799 -0.00431665 -0.02328692 -0.00870421 -0.00475675]
# We get cumulative change of:  0.012703406048062416
# vs adding way
# We get cumulative change of:  0.014443446893746659
# Using these changes: [-0.00431665 -0.02328692 -0.00870421 -0.00475675  0.02276799]
# We get cumulative change of:  -0.018708864001648617
# vs adding way
# We get cumulative change of:  -0.018296545573790013
# Using these changes: [-0.02328692 -0.00870421 -0.00475675  0.02276799  0.02406063]
# We get cumulative change of:  0.009258237987832096
# vs adding way
# We get cumulative change of:  0.01008073890278538
# Using these changes: [-0.00870421 -0.00475675  0.02276799  0.02406063 -0.00245973]
# We get cumulative change of:  0.030779422780988552
# vs adding way
# We get cumulative change of:  0.030907938318887163
# Using these changes: [-0.00475675  0.02276799  0.02406063 -0.00245973 -0.01754575]
# We get cumulative change of:  0.0215857210630499
# vs adding way
# We get cumulative change of:  0.022066398018890432
# Using these changes: [ 0.02276799  0.02406063 -0.00245973 -0.01754575 -0.00701251]
# We get cumulative change of:  0.019270251250192105
# vs adding way
# We get cumulative change of:  0.019810634600021526
# Using these changes: [ 0.02406063 -0.00245973 -0.01754575 -0.00701251  0.05966417]
# We get cumulative change of:  0.056040252217042674
# vs adding way
# We get cumulative change of:  0.05670681601336525
# ...
# vs adding way
# We get cumulative change of:  0.009898609922475043
# Using these changes: [-0.00252953 -0.0024259  -0.00232256 -0.00231992  0.01211706]
# We get cumulative change of:  0.002437743734452047
# vs adding way
# We get cumulative change of:  0.0025191495545445752
# Using these changes: [-0.0024259  -0.00232256 -0.00231992  0.01211706 -0.01767577]
# We get cumulative change of:  -0.012783917073730722
# vs adding way
# We get cumulative change of:  -0.012627084919044962
# Using these changes: [-0.00232256 -0.00231992  0.01211706 -0.01767577 -0.01952603]
# We get cumulative change of:  -0.029706487665007386
# vs adding way
# We get cumulative change of:  -0.029727209609615057
# Using these changes: [-0.00231992  0.01211706 -0.01767577 -0.01952603 -0.00097882]
# We get cumulative change of:  -0.028399634017411746
# vs adding way
# We get cumulative change of:  -0.028383473522103353
# Using these changes: [ 0.01211706 -0.01767577 -0.01952603 -0.00097882  0.0052991 ]
# We get cumulative change of:  -0.020979775126313882
# vs adding way
# We get cumulative change of:  -0.02076445064317811
# Using these changes: [-0.01767577 -0.01952603 -0.00097882  0.0052991   0.00613276]
# We get cumulative change of:  -0.026768379152252053
# vs adding way
# We get cumulative change of:  -0.02674874466178423
# Using these changes: [-0.01952603 -0.00097882  0.0052991   0.00613276  0.0017088 ]
# We get cumulative change of:  -0.007563237238752629
# vs adding way
# We get cumulative change of:  -0.007364174860789219
# Using these changes: [-0.00097882  0.0052991   0.00613276  0.0017088   0.00160742]
# We get cumulative change of:  0.013828061948786496
# vs adding way
# We get cumulative change of:  0.013769274566282519
# Using these changes: [0.0052991  0.00613276 0.0017088  0.00160742 0.00247219]
# We get cumulative change of:  0.01733021861331774
# vs adding way
# We get cumulative change of:  0.017220282501798412
# Using these changes: [0.00613276 0.0017088  0.00160742 0.00247219 0.01384022]
# We get cumulative change of:  0.025973549116577788
# vs adding way
# We get cumulative change of:  0.025761395552686084
# Using these changes: [0.0017088  0.00160742 0.00247219 0.01384022 0.02566033]
# We get cumulative change of:  0.04588619891916523
# vs adding way
# We get cumulative change of:  0.045288964658523057
# Using these changes: [0.00160742 0.00247219 0.01384022 0.02566033 0.01159912]
# We get cumulative change of:  0.05621269582328803
# vs adding way
# We get cumulative change of:  0.055179278590067105
# Using these changes: [ 0.00247219  0.01384022  0.02566033  0.01159912 -0.0012437 ]
# We get cumulative change of:  0.053206138902626376
# vs adding way
# We get cumulative change of:  0.05232815803046875
# Using these changes: [ 0.01384022  0.02566033  0.01159912 -0.0012437   0.00718222]
# We get cumulative change of:  0.05815453772492574
# vs adding way
# We get cumulative change of:  0.05703818773487879
# Using these changes: [ 0.02566033  0.01159912 -0.0012437   0.00718222 -0.00580122]
# We get cumulative change of:  0.03765458300487623
# vs adding way
# We get cumulative change of:  0.03739674804507409
# Using these changes: [ 0.01159912 -0.0012437   0.00718222 -0.00580122  0.02536889]
# We get cumulative change of:  0.037359730602073205
# vs adding way
# We get cumulative change of:  0.03710530384140531
# Using these changes: [-0.0012437   0.00718222 -0.00580122  0.02536889 -0.00187783]
# We get cumulative change of:  0.023539590472823724
# vs adding way
# We get cumulative change of:  0.023628357391578536
# Using these changes: [ 0.00718222 -0.00580122  0.02536889 -0.00187783 -0.00624777]
# We get cumulative change of:  0.01841134101431563
# vs adding way
# We get cumulative change of:  0.018624279855250947
# Using these changes: [-0.00580122  0.02536889 -0.00187783 -0.00624777  0.0095535 ]
# We get cumulative change of:  0.02080905667014754
# vs adding way
# We get cumulative change of:  0.020995558018251925
# Using these changes: [ 0.02536889 -0.00187783 -0.00624777  0.0095535   0.000587  ]
# We get cumulative change of:  0.02736826425352845
# vs adding way
# We get cumulative change of:  0.027383781275856722
# Using these changes: [-0.00187783 -0.00624777  0.0095535   0.000587    0.00900517]
# We get cumulative change of:  0.010972635460755109
# vs adding way
# We get cumulative change of:  0.011020060241909158
# Using these changes: [-0.00624777  0.0095535   0.000587    0.00900517 -0.00214694]
# We get cumulative change of:  0.010700057692602405
# vs adding way
# We get cumulative change of:  0.010750947207795014
# Using these changes: [ 0.0095535   0.000587    0.00900517 -0.00214694 -0.01836433]
# We get cumulative change of:  -0.00162313794577007
# vs adding way
# We get cumulative change of:  -0.0013656080476452948
# Using these changes: [ 0.000587    0.00900517 -0.00214694 -0.01836433  0.00137785]
# We get cumulative change of:  -0.009708269806738667
# vs adding way
# We get cumulative change of:  -0.009541251386904537
# Using these changes: [ 0.00900517 -0.00214694 -0.01836433  0.00137785  0.00792331]
# We get cumulative change of:  -0.0024474480134781817
# vs adding way
# We get cumulative change of:  -0.002204944644240814
# Using these changes: [-0.00214694 -0.01836433  0.00137785  0.00792331 -0.00463924]
# We get cumulative change of:  -0.01593698997934634
# vs adding way
# We get cumulative change of:  -0.01584935618565908
# Using these changes: [-0.01836433  0.00137785  0.00792331 -0.00463924 -0.00717675]
# We get cumulative change of:  -0.020897286835444784
# vs adding way
# We get cumulative change of:  -0.020879163554663904
# Using these changes: [ 0.00137785  0.00792331 -0.00463924 -0.00717675  0.00814132]
# We get cumulative change of:  0.005539963956888272
# vs adding way
# We get cumulative change of:  0.0056264809117722026
# Using these changes: [ 0.00792331 -0.00463924 -0.00717675  0.00814132  0.02003119]
# We get cumulative change of:  0.024270832629014416
# vs adding way
# We get cumulative change of:  0.024279819154567117
# Using these changes: [-0.00463924 -0.00717675  0.00814132  0.02003119  0.0340578 ]
# We get cumulative change of:  0.050829203063909256
# vs adding way
# We get cumulative change of:  0.05041431376689032
# Using these changes: [-0.00717675  0.00814132  0.02003119  0.0340578   0.04611654]
# We get cumulative change of:  0.10441345686828041
# vs adding way
# We get cumulative change of:  0.10117010093907497
# Using these changes: [ 0.00814132  0.02003119  0.0340578   0.04611654 -0.03271214]
# We get cumulative change of:  0.07600797126831593
# vs adding way
# We get cumulative change of:  0.07563471259951038
# Using these changes: [ 0.02003119  0.0340578   0.04611654 -0.03271214  0.00053393]
# We get cumulative change of:  0.06788847075253202
# vs adding way
# We get cumulative change of:  0.0680273303620943
# Using these changes: [ 0.0340578   0.04611654 -0.03271214  0.00053393  0.00237872]
# We get cumulative change of:  0.04940778583801975
# vs adding way
# We get cumulative change of:  0.05037485487132465
# Using these changes: [ 0.04611654 -0.03271214  0.00053393  0.00237872  0.00223342]
# We get cumulative change of:  0.017110993341350467
# vs adding way
# We get cumulative change of:  0.018550476685375794
# Using these changes: [-0.03271214  0.00053393  0.00237872  0.00223342 -0.00446453]
# We get cumulative change of:  -0.032067623584610905
# vs adding way
# We get cumulative change of:  -0.032030595666887374
# Using these changes: [ 0.00053393  0.00237872  0.00223342 -0.00446453 -0.00431916]
# We get cumulative change of:  -0.003655726230182621
# vs adding way
# We get cumulative change of:  -0.003637616896158491
# Using these changes: [ 0.00237872  0.00223342 -0.00446453 -0.00431916  0.00021223]
# We get cumulative change of:  -0.003976086939844303
# vs adding way
# We get cumulative change of:  -0.003959324732707659
# Using these changes: [ 0.00223342 -0.00446453 -0.00431916  0.00021223  0.00270326]
# We get cumulative change of:  -0.003653596794052305
# vs adding way
# We get cumulative change of:  -0.0036347770445535055
# Using these changes: [-0.00446453 -0.00431916  0.00021223  0.00270326 -0.00514583]
# We get cumulative change of:  -0.010989505286584711
# vs adding way
# We get cumulative change of:  -0.011014030543792575
# Using these changes: [-0.00431916  0.00021223  0.00270326 -0.00514583  0.00973672]
# We get cumulative change of:  0.0031186639004985306
# vs adding way
# We get cumulative change of:  0.003187216997476039
# Using these changes: [ 0.00021223  0.00270326 -0.00514583  0.00973672 -0.02027868]
# We get cumulative change of:  -0.012960079005541525
# vs adding way
# We get cumulative change of:  -0.012772306848599202
# Using these changes: [ 0.00270326 -0.00514583  0.00973672 -0.02027868  0.00138469]
# We get cumulative change of:  -0.011803053070743585
# vs adding way
# We get cumulative change of:  -0.011599840102277437
# Using these changes: [-0.00514583  0.00973672 -0.02027868  0.00138469  0.0006372 ]
# We get cumulative change of:  -0.013839224035381958
# vs adding way
# We get cumulative change of:  -0.013665901203200548
# Using these changes: [ 0.00973672 -0.02027868  0.00138469  0.0006372   0.00268942]
# We get cumulative change of:  -0.006072439425798382
# vs adding way
# We get cumulative change of:  -0.005830649341652339
# Using these changes: [-0.02027868  0.00138469  0.0006372   0.00268942  0.0020568 ]
# We get cumulative change of:  -0.013632112707215649
# vs adding way
# We get cumulative change of:  -0.013510564855682694
# Using these changes: [0.00138469 0.0006372  0.00268942 0.0020568  0.00097595]
# We get cumulative change of:  0.007766719156153901
# vs adding way
# We get cumulative change of:  0.0077440724653572435
# Using these changes: [0.0006372  0.00268942 0.0020568  0.00097595 0.00139683]
# We get cumulative change of:  0.007778935044925772
# vs adding way
# We get cumulative change of:  0.007756210992836188
# Using these changes: [ 0.00268942  0.0020568   0.00097595  0.00139683 -0.00114379]
# We get cumulative change of:  0.005985230534289787
# vs adding way
# We get cumulative change of:  0.005975217759343399
# Using these changes: [ 0.0020568   0.00097595  0.00139683 -0.00114379 -0.03443298]
# We get cumulative change of:  -0.031259191657688645
# vs adding way
# We get cumulative change of:  -0.031147184258605964
# Using these changes: [ 0.00097595  0.00139683 -0.00114379 -0.03443298  0.0052875 ]
# We get cumulative change of:  -0.028135910444249013
# vs adding way
# We get cumulative change of:  -0.027916490185761367
# Using these changes: [ 0.00139683 -0.00114379 -0.03443298  0.0052875  -0.0140435 ]
# We get cumulative change of:  -0.042718541983312375
# vs adding way
# We get cumulative change of:  -0.04293593957228958
# Using these changes: [-0.00114379 -0.03443298  0.0052875  -0.0140435  -0.01395282]
# We get cumulative change of:  -0.05739198405897705
# vs adding way
# We get cumulative change of:  -0.05828559276061629
# Using these changes: [-0.03443298  0.0052875  -0.0140435  -0.01395282 -0.02119684]
# We get cumulative change of:  -0.07631579393966681
# vs adding way
# We get cumulative change of:  -0.07833864205396346
# Using these changes: [ 0.0052875  -0.0140435  -0.01395282 -0.02119684 -0.00019073]
# We get cumulative change of:  -0.04355885221306144
# vs adding way
# We get cumulative change of:  -0.044096395199692995
# Using these changes: [-0.0140435  -0.01395282 -0.02119684 -0.00019073  0.02517644]
# We get cumulative change of:  -0.02463629990113092
# vs adding way
# We get cumulative change of:  -0.02420745033773708
# Using these changes: [-0.01395282 -0.02119684 -0.00019073  0.02517644  0.02468285]
# We get cumulative change of:  0.013673979219940069
# vs adding way
# We get cumulative change of:  0.014518892312758824
# Using these changes: [-0.02119684 -0.00019073  0.02517644  0.02468285  0.02301321]
# We get cumulative change of:  0.05167571251739744
# vs adding way
# We get cumulative change of:  0.0514849214419385
# Using these changes: [-0.00019073  0.02517644  0.02468285  0.02301321  0.03614627]
# We get cumulative change of:  0.11328805415312426
# vs adding way
# We get cumulative change of:  0.10882803014650311
# Using these changes: [0.02517644 0.02468285 0.02301321 0.03614627 0.01033465]
# We get cumulative change of:  0.12500806837850265
# vs adding way
# We get cumulative change of:  0.11935340925538207
# Using these changes: [0.02468285 0.02301321 0.03614627 0.01033465 0.01497878]
# We get cumulative change of:  0.113817363741602
# vs adding way
# We get cumulative change of:  0.10915575193633287
# Using these changes: [ 0.02301321  0.03614627  0.01033465  0.01497878 -0.00091883]
# We get cumulative change of:  0.08598866193392629
# vs adding way
# We get cumulative change of:  0.08355407404239845
# Using these changes: [ 0.03614627  0.01033465  0.01497878 -0.00091883 -0.01353027]
# We get cumulative change of:  0.047195614247709905
# vs adding way
# We get cumulative change of:  0.0470105985122895
# Using these changes: [ 0.01033465  0.01497878 -0.00091883 -0.01353027  0.00857034]
# We get cumulative change of:  0.019325617306712894
# vs adding way
# We get cumulative change of:  0.019434668137944033
# Using these changes: [ 0.01497878 -0.00091883 -0.01353027  0.00857034 -0.00195094]
# We get cumulative change of:  0.006930703379412151
# vs adding way
# We get cumulative change of:  0.007149083670285328
# Using these changes: [-0.00091883 -0.01353027  0.00857034 -0.00195094  0.00461881]
# We get cumulative change of:  -0.003347121673510367
# vs adding way
# We get cumulative change of:  -0.0032108888141958447
# Using these changes: [-0.01353027  0.00857034 -0.00195094  0.00461881  0.00374913]
# We get cumulative change of:  0.0013094945655021117
# vs adding way
# We get cumulative change of:  0.001457073015250554
# Using these changes: [ 0.00857034 -0.00195094  0.00461881  0.00374913  0.00522489]
# We get cumulative change of:  0.020346797849373432
# vs adding way
# We get cumulative change of:  0.02021223667427685
# Using these changes: [-0.00195094  0.00461881  0.00374913  0.00522489 -0.044338  ]
# We get cumulative change of:  -0.033179315758829264
# vs adding way
# We get cumulative change of:  -0.03269609864827827
# Using these changes: [ 0.00461881  0.00374913  0.00522489 -0.044338   -0.00876684]
# We get cumulative change of:  -0.03978194778094024
# vs adding way
# We get cumulative change of:  -0.03951199615530654
# Using these changes: [ 0.00374913  0.00522489 -0.044338   -0.00876684  0.00772208]
# We get cumulative change of:  -0.03681583594534821
# vs adding way
# We get cumulative change of:  -0.03640873045221138
# Using these changes: [ 0.00522489 -0.044338   -0.00876684  0.00772208 -0.00233353]
# We get cumulative change of:  -0.04265267704198561
# vs adding way
# We get cumulative change of:  -0.04249139293063253
# Using these changes: [-0.044338   -0.00876684  0.00772208 -0.00233353  0.01178842]
# We get cumulative change of:  -0.03640176106514492
# vs adding way
# We get cumulative change of:  -0.035927864520563624
# Using these changes: [-0.00876684  0.00772208 -0.00233353  0.01178842 -0.01181778]
# We get cumulative change of:  -0.003611480627513819
# vs adding way
# We get cumulative change of:  -0.003407646212794546
# Using these changes: [ 0.00772208 -0.00233353  0.01178842 -0.01181778  0.02856758]
# We get cumulative change of:  0.0339171051299223
# vs adding way
# We get cumulative change of:  0.03392676508156722
# Using these changes: [-0.00233353  0.01178842 -0.01181778  0.02856758  0.01018772]
# We get cumulative change of:  0.03644683657133507
# vs adding way
# We get cumulative change of:  0.03639240397261079
# Using these changes: [ 0.01178842 -0.01181778  0.02856758  0.01018772  0.00278555]
# We get cumulative change of:  0.041764907899172865
# vs adding way
# We get cumulative change of:  0.04151149088580908
# Using these changes: [-0.01181778  0.02856758  0.01018772  0.00278555  0.00713266]
# We get cumulative change of:  0.036971208366311625
# vs adding way
# We get cumulative change of:  0.036855728676061905
# Using these changes: [ 0.02856758  0.01018772  0.00278555  0.00713266 -0.00136506]
# We get cumulative change of:  0.047940005193264135
# vs adding way
# We get cumulative change of:  0.04730844899187536
# Using these changes: [ 0.01018772  0.00278555  0.00713266 -0.00136506 -0.00211238]
# We get cumulative change of:  0.016682209986368823
# vs adding way
# We get cumulative change of:  0.016628491687339042

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, 
               input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))  # Output layer - predicting the price change

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Make predictions
y_pred = model.predict(X_test)

# Inverse transform to get real values
y_pred_actual = y_scaler.inverse_transform(y_pred)
y_test_actual = y_scaler.inverse_transform(y_test)

# Evaluate the model
mse = np.mean((y_pred_actual - y_test_actual) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# Epoch 1/100
# c:\Users\matth\Uni work\Year 3\Spring Semester\CM3203 - One Semester Individual Project\Project Environment\CM3202-Venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0205 - val_loss: 0.0032
# Epoch 2/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 3/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 4/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043 - val_loss: 0.0030
# Epoch 5/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 6/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 7/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 8/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 9/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 10/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 11/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 12/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 13/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 14/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 15/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 16/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 17/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 18/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 19/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 20/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 21/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 22/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 23/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 24/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 25/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 26/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 27/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 28/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 29/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 30/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 31/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 32/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 33/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 34/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 35/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 36/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 37/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 38/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 39/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 40/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 41/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 42/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 43/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 44/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 45/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 46/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 47/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 48/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 49/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 50/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 51/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 52/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 53/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 54/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 55/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 56/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 57/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 58/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 59/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 60/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 61/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 62/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 63/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 64/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 65/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 66/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 67/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 68/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 69/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 70/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 71/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 72/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 73/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 74/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 75/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 76/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 77/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 78/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 79/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 80/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 81/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 82/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 83/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 84/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 85/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 86/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 87/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 88/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 89/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 90/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 91/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 92/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 93/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 94/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 95/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 96/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 97/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 98/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 99/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 100/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - val_loss: 0.0034
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Mean Squared Error: 0.003580652943479827

# %%
# Modified MAPE calculation with safeguards
def calculate_mape(y_true, y_pred):
    # Filter out zeros in actual values to avoid division by zero
    mask = y_true.flatten() != 0
    if not np.any(mask):  # If all values are zero
        return "Cannot calculate MAPE: All actual values are zero"
    
    # Calculate MAPE only for non-zero actual values
    percentage_errors = np.abs((y_true.flatten()[mask] - y_pred.flatten()[mask]) / y_true.flatten()[mask]) * 100
    
    # Remove infinite or extremely large values (optional)
    filtered_errors = percentage_errors[~np.isinf(percentage_errors) & (percentage_errors < 1000)]
    
    if len(filtered_errors) == 0:
        return "Cannot calculate meaningful MAPE: Errors too large or undefined"
    
    return np.mean(filtered_errors)

# Using the function
mape_value = calculate_mape(y_test_actual, y_pred_actual)
print(f"Mean Absolute Percentage Error: {mape_value}%")
# Out:
# Mean Absolute Percentage Error: 152.57233407273944%

# %%
# Plot actual vs predicted

def plot_actual_vs_predicted(y_test_actual, y_pred_actual):
    """
    Create comprehensive plots comparing actual vs predicted price changes.
    
    Parameters:
    y_test_actual - numpy array of actual price changes
    y_pred_actual - numpy array of predicted price changes
    """
    # Ensure inputs are flattened
    y_test_actual = y_test_actual.flatten()
    y_pred_actual = y_pred_actual.flatten()
    
    # Create a figure with 2x2 subplots
    fig, axs = plt.subplots(2, 2, figsize=(16, 12))
    
    # 1. Time series plot of actual vs predicted values
    axs[0, 0].plot(y_test_actual, label='Actual', linewidth=2)
    axs[0, 0].plot(y_pred_actual, label='Predicted', linewidth=2, linestyle='--')
    axs[0, 0].set_title('Actual vs Predicted Price Changes Over Time', fontsize=14)
    axs[0, 0].set_xlabel('Sample Index', fontsize=12)
    axs[0, 0].set_ylabel('Price Change', fontsize=12)
    axs[0, 0].legend(fontsize=12)
    axs[0, 0].grid(True)
    
    # 2. Scatter plot of actual vs predicted with diagonal line
    axs[0, 1].scatter(y_test_actual, y_pred_actual, alpha=0.6)
    
    # Add diagonal line (perfect predictions)
    min_val = min(y_test_actual.min(), y_pred_actual.min())
    max_val = max(y_test_actual.max(), y_pred_actual.max())
    axs[0, 1].plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    
    axs[0, 1].set_title('Scatter Plot of Actual vs Predicted Values', fontsize=14)
    axs[0, 1].set_xlabel('Actual Price Change', fontsize=12)
    axs[0, 1].set_ylabel('Predicted Price Change', fontsize=12)
    axs[0, 1].grid(True)
    
    # 3. Histogram of errors
    errors = y_test_actual - y_pred_actual
    axs[1, 0].hist(errors, bins=30, alpha=0.7, color='blue')
    axs[1, 0].axvline(x=0, color='r', linestyle='--', linewidth=2)
    axs[1, 0].set_title('Distribution of Prediction Errors', fontsize=14)
    axs[1, 0].set_xlabel('Error (Actual - Predicted)', fontsize=12)
    axs[1, 0].set_ylabel('Frequency', fontsize=12)
    axs[1, 0].grid(True)
    
    # 4. Directional accuracy visualization
    correct_direction = np.sign(y_test_actual) == np.sign(y_pred_actual)
    axs[1, 1].bar(['Correct Direction', 'Wrong Direction'], 
                 [np.sum(correct_direction), np.sum(~correct_direction)],
                 color=['green', 'red'])
    
    directional_accuracy = np.mean(correct_direction) * 100
    axs[1, 1].set_title(f'Directional Accuracy: {directional_accuracy:.2f}%', fontsize=14)
    axs[1, 1].set_ylabel('Count', fontsize=12)
    axs[1, 1].grid(True, axis='y')
    
    plt.tight_layout()
    plt.show()

plot_actual_vs_predicted(y_test_actual, y_pred_actual)

# %%
# Evaluate accuracy of predictions for the top x percent of predictions by size of change
# 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
 
def compare_estimate_to_real(y_test_actual, y_pred_actual, percentage=5):
    """
    Create comprehensive plots comparing actual vs predicted price changes.
    
    Parameters:
    y_test_actual - numpy array of actual price changes
    y_pred_actual - numpy array of predicted price changes
    """
    # Ensure inputs are flattened
    y_test_actual = y_test_actual.flatten()
    y_pred_actual = y_pred_actual.flatten()

    # Find the indices of the top positive and negative predicted changes
    num_to_highlight = int(len(y_pred_actual) * percentage / 100)
    
    # Sort by absolute value to get largest changes in either direction
    sorted_indices = np.argsort(np.abs(y_pred_actual))[::-1]
    top_indices = sorted_indices[:num_to_highlight]

    top_predicted = y_pred_actual[top_indices]
    real_equivalents = y_test_actual[top_indices]

     # Compute error metrics
    overall_mae = mean_absolute_error(y_test_actual, y_pred_actual)
    top_mae = mean_absolute_error(real_equivalents, top_predicted)

    overall_rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual))
    top_rmse = np.sqrt(mean_squared_error(real_equivalents, top_predicted))

    overall_r2 = r2_score(y_test_actual, y_pred_actual)
    top_r2 = r2_score(real_equivalents, top_predicted)

    # Directional Accuracy: % of cases where sign of predicted matches actual
    overall_directional_accuracy = np.mean(np.sign(y_pred_actual) == np.sign(y_test_actual))
    top_directional_accuracy = np.mean(np.sign(top_predicted) == np.sign(real_equivalents))

    print(f"Overall MAE: {overall_mae:.4f}, Top {percentage}% MAE: {top_mae:.4f}")
    print(f"Overall RMSE: {overall_rmse:.4f}, Top {percentage}% RMSE: {top_rmse:.4f}")
    print(f"Overall R²: {overall_r2:.4f}, Top {percentage}% R²: {top_r2:.4f}")
    print(f"Overall Directional Accuracy: {overall_directional_accuracy:.2%}")
    print(f"Top {percentage}% Directional Accuracy: {top_directional_accuracy:.2%}")


compare_estimate_to_real(y_test_actual, y_pred_actual)
# Out:
# Overall MAE: 0.0438, Top 5% MAE: 0.0630
# Overall RMSE: 0.0598, Top 5% RMSE: 0.0777
# Overall R²: -0.1006, Top 5% R²: -1.5758
# Overall Directional Accuracy: 53.39%
# Top 5% Directional Accuracy: 66.67%

# %%
def plot_top_predicted_price_changes(cleaned_df, y_pred_actual, percentage=10):
    """
    Plot the actual price chart and highlight where the model predicts the largest price changes.
    
    Parameters:
    cleaned_df - The original DataFrame with token prices
    y_pred_actual - numpy array of predicted price changes (percentage)
    percentage - Top percentage of price changes to highlight (default: 10%)
    """
    import matplotlib.dates as mdates
    from matplotlib.patches import Rectangle
    
    # Flatten the predictions if needed
    y_pred_actual = y_pred_actual.flatten()
    
    # Determine where the test predictions start in the cleaned dataframe
    test_start = len(cleaned_df) - len(y_pred_actual)
    
    # Get the actual token prices for the test period
    actual_prices = cleaned_df['token_price'].values[test_start:]
    
    # Get the timestamps or indices
    if 'block_time' in cleaned_df.columns:
        time_axis = cleaned_df['block_time'].values[test_start:]
    elif 'slot' in cleaned_df.columns:
        time_axis = cleaned_df['slot'].values[test_start:]
    else:
        time_axis = np.arange(len(actual_prices))
    
    # Find the indices of the top positive and negative predicted changes
    num_to_highlight = int(len(y_pred_actual) * percentage / 100)
    
    # Sort by absolute value to get largest changes in either direction
    sorted_indices = np.argsort(np.abs(y_pred_actual))[::-1]
    top_indices = sorted_indices[:num_to_highlight]
    
    # Separate positive and negative changes
    positive_indices = [i for i in top_indices if y_pred_actual[i] > 0]
    negative_indices = [i for i in top_indices if y_pred_actual[i] < 0]
    
    # Create the plot
    plt.figure(figsize=(14, 7))
    
    # Plot the actual price line
    plt.plot(time_axis, actual_prices, label='Actual Price', color='blue', linewidth=2)
    
    # Plot markers for top positive predicted changes
    if positive_indices:
        plt.scatter(
            time_axis[positive_indices], 
            actual_prices[positive_indices], 
            color='green', 
            s=100, 
            marker='^', 
            label=f'Top {percentage}% Positive Predicted Changes'
        )
        
        # Annotate positive changes with the predicted percentage
        for idx in positive_indices:
            plt.annotate(
                f"+{y_pred_actual[idx]:.2f}%", 
                (time_axis[idx], actual_prices[idx]),
                xytext=(5, 10),
                textcoords='offset points',
                color='darkgreen',
                fontweight='bold'
            )
    
    # Plot markers for top negative predicted changes
    if negative_indices:
        plt.scatter(
            time_axis[negative_indices], 
            actual_prices[negative_indices], 
            color='red', 
            s=100, 
            marker='v', 
            label=f'Top {percentage}% Negative Predicted Changes'
        )
        
        # Annotate negative changes with the predicted percentage
        for idx in negative_indices:
            plt.annotate(
                f"{y_pred_actual[idx]:.2f}%", 
                (time_axis[idx], actual_prices[idx]),
                xytext=(5, -20),
                textcoords='offset points',
                color='darkred',
                fontweight='bold'
            )
    
    # Add titles and labels
    plt.title(f'Token Price with Top {percentage}% Predicted Price Changes', fontsize=16)
    plt.xlabel('Time', fontsize=14)
    plt.ylabel('Token Price', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    # Format x-axis if using datetime
    if hasattr(time_axis[0], 'dtype') and np.issubdtype(time_axis[0].dtype, np.datetime64):
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
        plt.gcf().autofmt_xdate()
    
    plt.tight_layout()
    plt.show()
    
    # Also create a second plot showing the distribution of predicted changes
    plt.figure(figsize=(12, 5))
    
    # Plot histogram of all predicted changes
    plt.hist(y_pred_actual, bins=30, alpha=0.5, color='blue', label='All Predictions')
    
    # Highlight thresholds used for top changes
    if len(y_pred_actual) > 0:
        # Find thresholds
        sorted_positive = np.sort(y_pred_actual[y_pred_actual > 0])
        sorted_negative = np.sort(y_pred_actual[y_pred_actual < 0])
        
        positive_threshold = sorted_positive[-min(num_to_highlight, len(sorted_positive))] if len(sorted_positive) > 0 else 0
        negative_threshold = sorted_negative[min(num_to_highlight, len(sorted_negative))-1] if len(sorted_negative) > 0 else 0
        
        # Plot vertical lines at thresholds
        if positive_threshold > 0:
            plt.axvline(x=positive_threshold, color='green', linestyle='--', 
                       label=f'Positive Threshold: {positive_threshold:.2f}%')
        
        if negative_threshold < 0:
            plt.axvline(x=negative_threshold, color='red', linestyle='--',
                       label=f'Negative Threshold: {negative_threshold:.2f}%')
    
    plt.title('Distribution of Predicted Price Changes', fontsize=16)
    plt.xlabel('Predicted Change (%)', fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# Example usage:
plot_top_predicted_price_changes(cleaned_df, y_pred_actual, percentage=5)
